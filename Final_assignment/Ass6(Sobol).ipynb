# %% [markdown]
# ### Sensitivity analysis --> Sobol
# Defining parameters to vary and find variance on parameters outcome --> damage important to all actors
# Finding variance that explains that damage is highest in other scenarios --> RfR & damage is low --> dike heightening

# %%
## Importing all functions

# %matplotlib inline
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

from ema_workbench import (Model, RealParameter, TimeSeriesOutcome,
                           perform_experiments, ema_logging,Policy)

from ema_workbench import Samplers

from ema_workbench.analysis import feature_scoring
from ema_workbench.analysis.scenario_discovery_util import RuleInductionType
from ema_workbench.em_framework.salib_samplers import get_SALib_problem

from ema_workbench.analysis.scenario_discovery_util import RuleInductionType

from ema_workbench.util import ema_logging

from dike_model_function import DikeNetwork

# exp, out = evaluator.perform_experiments(...,uncertainty_sampling=Samplers.SOBOL)

from SALib.analyze import sobol

# %%
from ema_workbench import (
    Model,
    RealParameter,
    IntegerParameter,
    CategoricalParameter,
    ScalarOutcome,
    Samplers,
    perform_experiments
)
from ema_workbench.em_framework import Samplers
from ema_workbench.em_framework.salib_samplers import (get_SALib_problem)
from dike_model_function import DikeNetwork
from ema_workbench.util import ema_logging
from SALib.analyze import sobol

# Define the sum_over function
def sum_over(*args):
    numbers = []
    for entry in args:
        try:
            value = sum(entry)
        except TypeError:
            value = entry
        numbers.append(value)
    return sum(numbers)

# Configure logging
ema_logging.log_to_stderr(ema_logging.INFO)

# Define the function to get the model for the given problem formulation
def get_model_for_problem_formulation(problem_formulation_id):
    function = DikeNetwork()
    dike_model = Model("dikesnet", function=function)

    Real_uncert = {"Bmax": [30, 350], "pfail": [0, 1]}  # m and [.]
    cat_uncert_loc = {"Brate": (1.0, 1.5, 10)}
    cat_uncert = {f"discount rate {n}": (1.5, 2.5, 3.5, 4.5) for n in function.planning_steps}
    Int_uncert = {"A.0_ID flood wave shape": [0, 132]}

    uncertainties = []

    for uncert_name in cat_uncert.keys():
        categories = cat_uncert[uncert_name]
        uncertainties.append(CategoricalParameter(uncert_name, categories))

    for uncert_name in Int_uncert.keys():
        uncertainties.append(IntegerParameter(uncert_name, Int_uncert[uncert_name][0], Int_uncert[uncert_name][1]))

    dike_height_levers = []
    for dike in function.dikelist:
        for uncert_name in Real_uncert.keys():
            name = f"{dike}_{uncert_name}"
            lower, upper = Real_uncert[uncert_name]
            uncertainties.append(RealParameter(name, lower, upper))

        for uncert_name in cat_uncert_loc.keys():
            name = f"{dike}_{uncert_name}"
            categories = cat_uncert_loc[uncert_name]
            uncertainties.append(CategoricalParameter(name, categories))
        
        for n in function.planning_steps:
            name = f"{dike}_DikeIncrease {n}"
            dike_height_levers.append(IntegerParameter(name, 0, 10))
        
    dike_model.uncertainties = uncertainties

    dike_height_levers.append(IntegerParameter("EWS_DaysToThreat", 0, 4))  # days
    # Set levers: No RfR, dike heightening
    dike_model.levers = dike_height_levers

    # Define the outcomes
    outcomes = [
        ScalarOutcome('Total Costs', kind=ScalarOutcome.MINIMIZE, function=sum_over, variable_name=[
            f"{dike}_Expected Annual Damage" for dike in function.dikelist] +
            [f"{dike}_Dike Investment Costs" for dike in function.dikelist] +
            ["RfR Total Costs"] 
        ),
        ScalarOutcome('Expected Number of Deaths', kind=ScalarOutcome.MINIMIZE, function=sum_over, variable_name=[
            f"{dike}_Expected Number of Deaths" for dike in function.dikelist]
        ),
        ScalarOutcome('Expected Annual Damage', kind=ScalarOutcome.MINIMIZE, function=sum_over, variable_name=[
            f"{dike}_Expected Annual Damage" for dike in function.dikelist]),
        ScalarOutcome('Dike Investment Costs', kind=ScalarOutcome.MINIMIZE, function=sum_over, variable_name=[f"{dike}_Dike Investment Costs" for dike in function.dikelist]),
        ScalarOutcome('RfR Total Costs', kind=ScalarOutcome.MINIMIZE, function=sum_over, variable_name=["RfR Total Costs"] )
    ]
    
    # 
    # # Define the levers
    # levers = [
    #     # Range of dike heightening:
    #     IntegerParameter("DikeIncrease", 0, 10),  # dm
    # 
    #     # Series of five Room for the River projects:
    #     *[CategoricalParameter(f"{project_id}_RfR", [0, 1]) for project_id in range(0, 5)],
    # 
    #     # Time of warning: 0, 1, 2, 3, 4 days ahead from the flood
    #     IntegerParameter("EWS_DaysToThreat", 0, 4)  # days
    # ]

    # Assign uncertainties, outcomes, and levers to the model
    # dike_model.uncertainties = uncertainties
    dike_model.outcomes = outcomes
    
    # dike_model.levers = levers 

    return dike_model

# Define policies to test different dike height increases
policies = [Policy(f"DikeIncrease_{i}", **{f"{dike}_DikeIncrease {n}": i for dike in dike_model.function.dikelist for n in dike_model.function.planning_steps}, **{"EWS_DaysToThreat": 2}) for i in range(1, 11, 2)]



# Get the model for a specific problem formulation
problem_formulation_id = 6  # Change this to the desired problem formulation
dike_model = get_model_for_problem_formulation(problem_formulation_id)

# Get SALib problem
problem = get_SALib_problem(dike_model.uncertainties)

# Print the problem definition
print(problem)

# %%
n_exp = 750

experiments_sobol, outcomes_sobol = perform_experiments(dike_model, scenarios=n_exp,
                                                        policies=policies,
                                                        uncertainty_sampling=Samplers.SOBOL)

dike_final_sobol = outcomes_sobol["Total Costs"][:,0,-1]
dike_mean_sobol = np.mean(outcomes_sobol["Total Costs"][:,0,:],axis=1)
dike_std_sobol = np.std(outcomes_sobol["Total Costs"][:,0,:],axis=1)

Si = sobol.analyze(problem, dike_mean_sobol, calc_second_order=True, print_to_console=True)

# %%
import pandas as pd
experiments_sobol.to_csv('experiments_sobol.csv')
outcomes_df = pd.DataFrame(outcomes_sobol)
outcomes_df.to_csv('outcomes_sobol.csv', index=False)

# %%
dike_final_sobol = outcomes_sobol["Total Costs"]
dike_mean_sobol = np.mean(outcomes_sobol["Total Costs"])
dike_std_sobol = np.std(outcomes_sobol["Total Costs"])

# Check the shape of the data
print(f"Shape of outcomes_sobol['Total Costs']: {outcomes_sobol['Total Costs'].shape}")

# Ensure we use the correct number of samples
N = outcomes_sobol['Total Costs'].shape[0]

# Sobol analysis
try:
    Si = sobol.analyze(problem, outcomes_sobol['Total Costs'], calc_second_order=True, print_to_console=True)
    print("Sobol analysis completed successfully")
except Exception as e:
    print(f"Error during Sobol analysis: {e}")

# %%
Si_filter = {k:Si[k] for k in ['ST','ST_conf','S1','S1_conf']}
Si_df = pd.DataFrame(Si_filter, index=problem['names'])

sns.set_style('white')
fig, ax = plt.subplots(1)

indices = Si_df[['S1','ST']]
err = Si_df[['S1_conf','ST_conf']]

indices.plot.bar(yerr=err.values.T,ax=ax)
fig.set_size_inches(8,6)
fig.subplots_adjust(bottom=0.3)
plt.show()

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from SALib.analyze import sobol

# Check the shape of the data
print(f"Shape of outcomes_sobol['Total Costs']: {outcomes_sobol['Total Costs'].shape}")

# Perform Sobol analysis
n_exp = outcomes_sobol['Total Costs'].shape[0]

# DataFrame to store Sobol indices
s_data = pd.DataFrame(index=problem['names'], columns=np.arange(20, n_exp, 50) * (2 * problem['num_vars'] + 2))

try:
    # Using tqdm to show progress
    for j in tqdm(s_data.columns, desc="Sobol Analysis Progress"):
        # Ensure Y is properly indexed
        scores = sobol.analyze(problem, outcomes_sobol['Total Costs'][0:j], calc_second_order=True, print_to_console=False)
        s_data.loc[:, j] = scores['ST']
    print("Sobol analysis completed successfully")
except IndexError as e:
    print(f"IndexError during Sobol analysis: {e}")
except Exception as e:
    print(f"Error during Sobol analysis: {e}")

# Print the resulting DataFrame
print(s_data)

# %%
fig, ax = plt.subplots(1)

s_data.T.plot(ax=ax)
ax.set_xlabel('Samples')
ax.set_ylabel('Total index (ST)')
plt.show()

# %% [markdown]
# ##Extra Trees##

# %%
from ema_workbench.analysis import feature_scoring

# %%
dike_final_sobol = outcomes_sobol["Total Costs"]
dike_mean_sobol = np.mean(outcomes_sobol["Total Costs"])
dike_std_sobol = np.std(outcomes_sobol["Total Costs"])

# %%
res = feature_scoring.get_ex_feature_scores(experiments_sobol, dike_final_sobol,
                                      max_features=0.6, mode=RuleInductionType.REGRESSION)[0]
scores
# Out:
# C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
#                             33500
# 0
# A.1_pfail                0.639911
# A.3_pfail                0.189355
# A.5_pfail                0.020151
# discount rate 0          0.019271
# A.2_pfail                0.014930
# discount rate 1          0.013387
# discount rate 2          0.009444
# Unnamed: 0               0.005047
# policy                   0.005029
# A.1_Bmax                 0.004782
# A.5_DikeIncrease 0       0.004710
# A.3_Bmax                 0.004073
# A.5_Bmax                 0.003934
# A.4_pfail                0.003889
# A.3_DikeIncrease 2       0.003780
# A.0_ID flood wave shape  0.003595
# A.5_DikeIncrease 2       0.003559
# A.4_Bmax                 0.003491
# A.2_Bmax                 0.003454
# A.5_DikeIncrease 1       0.003436
# A.1_Brate                0.003262
# A.4_DikeIncrease 0       0.003143
# A.4_Brate                0.003038
# A.2_Brate                0.003030
# A.3_Brate                0.003010
# A.4_DikeIncrease 1       0.002904
# A.3_DikeIncrease 0       0.002891
# A.5_Brate                0.002731
# A.4_DikeIncrease 2       0.002580
# A.2_DikeIncrease 0       0.002441
# A.1_DikeIncrease 2       0.002423
# A.1_DikeIncrease 1       0.002248
# A.1_DikeIncrease 0       0.001955
# A.2_DikeIncrease 1       0.001896
# A.2_DikeIncrease 2       0.001795
# A.3_DikeIncrease 1       0.001428
# EWS_DaysToThreat         0.000000

# %%
import pandas as pd
import numpy as np
from ema_workbench.analysis import feature_scoring
from ema_workbench.analysis.feature_scoring import RuleInductionType
from tqdm import tqdm  # Import tqdm for the progress bar

# Assuming outcomes_sobol and experiments_sobol are loaded correctly as previously mentioned

# Ensure dike_mean_sobol is correctly calculated as an array
dike_mean_sobol = np.mean(outcomes_sobol["Total Costs"].reshape(-1, 1), axis=1)

combined_scores = []

# Adding a progress bar to the loop
for j in tqdm(range(100, experiments_sobol.shape[0], 100), desc="Feature Scoring Progress"):
    scores = feature_scoring.get_ex_feature_scores(experiments_sobol.iloc[0:j, :],
                                                   dike_mean_sobol[0:j],
                                                   max_features=0.6,
                                                   mode=RuleInductionType.REGRESSION)[0]
    scores.columns = [j]
    combined_scores.append(scores)

# Combine the scores DataFrames
combined_scores_df = pd.concat(combined_scores, axis=1)

# Optionally, print or save the combined_scores_df
print(combined_scores_df)
# Out:
# Feature Scoring Progress:   0%|          | 0/1499 [00:00<?, ?it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   0%|          | 1/1499 [00:00<04:17,  5.82it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   0%|          | 2/1499 [00:00<04:03,  6.15it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   0%|          | 3/1499 [00:00<04:41,  5.31it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   0%|          | 4/1499 [00:00<05:08,  4.84it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   0%|          | 5/1499 [00:01<05:31,  4.50it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   0%|          | 6/1499 [00:01<06:09,  4.04it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   0%|          | 7/1499 [00:01<08:12,  3.03it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|          | 8/1499 [00:02<09:10,  2.71it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|          | 9/1499 [00:02<09:56,  2.50it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|          | 10/1499 [00:03<10:17,  2.41it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|          | 11/1499 [00:03<10:32,  2.35it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|          | 12/1499 [00:04<10:53,  2.27it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|          | 13/1499 [00:04<12:02,  2.06it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|          | 14/1499 [00:05<12:29,  1.98it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|          | 15/1499 [00:05<12:48,  1.93it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|          | 16/1499 [00:06<13:21,  1.85it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|          | 17/1499 [00:06<13:45,  1.79it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|          | 18/1499 [00:07<14:29,  1.70it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|▏         | 19/1499 [00:08<15:11,  1.62it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|▏         | 20/1499 [00:09<15:50,  1.56it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|▏         | 21/1499 [00:09<16:51,  1.46it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   1%|▏         | 22/1499 [00:10<17:27,  1.41it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 23/1499 [00:11<15:55,  1.55it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 24/1499 [00:11<14:56,  1.65it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 25/1499 [00:12<14:22,  1.71it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 26/1499 [00:12<14:08,  1.74it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 27/1499 [00:13<14:09,  1.73it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 28/1499 [00:13<14:10,  1.73it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 29/1499 [00:14<14:31,  1.69it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 30/1499 [00:15<14:52,  1.65it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 31/1499 [00:15<14:59,  1.63it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 32/1499 [00:16<15:20,  1.59it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 33/1499 [00:17<15:40,  1.56it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 34/1499 [00:17<16:00,  1.53it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 35/1499 [00:18<16:28,  1.48it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 36/1499 [00:19<16:47,  1.45it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   2%|▏         | 37/1499 [00:19<17:07,  1.42it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 38/1499 [00:20<17:35,  1.38it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 39/1499 [00:21<18:00,  1.35it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 40/1499 [00:22<18:21,  1.32it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 41/1499 [00:23<18:55,  1.28it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 42/1499 [00:23<19:24,  1.25it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 43/1499 [00:24<19:58,  1.22it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 44/1499 [00:25<20:22,  1.19it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 45/1499 [00:26<20:44,  1.17it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 46/1499 [00:27<21:12,  1.14it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 47/1499 [00:28<21:39,  1.12it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 48/1499 [00:29<22:10,  1.09it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 49/1499 [00:30<22:41,  1.06it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 50/1499 [00:31<23:07,  1.04it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 51/1499 [00:32<23:39,  1.02it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   3%|▎         | 52/1499 [00:33<24:00,  1.00it/s]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   4%|▎         | 53/1499 [00:34<24:24,  1.01s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   4%|▎         | 54/1499 [00:35<24:47,  1.03s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   4%|▎         | 55/1499 [00:36<25:08,  1.04s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   4%|▎         | 56/1499 [00:37<25:30,  1.06s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   4%|▍         | 57/1499 [00:38<25:59,  1.08s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   4%|▍         | 58/1499 [00:40<26:27,  1.10s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   4%|▍         | 59/1499 [00:41<26:53,  1.12s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   4%|▍         | 60/1499 [00:42<27:21,  1.14s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   4%|▍         | 61/1499 [00:43<27:48,  1.16s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:   4%|▍         |
/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  22%|██▏       | 327/1499 [14:12<1:38:38,  5.05s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  22%|██▏       | 328/1499 [14:17<1:38:55,  5.07s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  22%|██▏       | 329/1499 [14:22<1:39:12,  5.09s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  22%|██▏       | 330/1499 [14:28<1:39:15,  5.09s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  22%|██▏       | 331/1499 [14:33<1:40:16,  5.15s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  22%|██▏       | 332/1499 [14:38<1:40:32,  5.17s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  22%|██▏       | 333/1499 [14:43<1:40:48,  5.19s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  22%|██▏       | 334/1499 [14:49<1:40:49,  5.19s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  22%|██▏       | 335/1499 [14:54<1:40:50,  5.20s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  22%|██▏       | 336/1499 [14:59<1:41:05,  5.22s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  22%|██▏       | 337/1499 [15:04<1:41:08,  5.22s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 338/1499 [15:10<1:41:25,  5.24s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 339/1499 [15:15<1:41:03,  5.23s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 340/1499 [15:20<1:41:30,  5.25s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 341/1499 [15:25<1:41:35,  5.26s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 342/1499 [15:31<1:41:36,  5.27s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 343/1499 [15:36<1:41:42,  5.28s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 344/1499 [15:41<1:42:05,  5.30s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 345/1499 [15:47<1:42:00,  5.30s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 346/1499 [15:52<1:42:40,  5.34s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 347/1499 [15:57<1:42:19,  5.33s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 348/1499 [16:03<1:42:52,  5.36s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 349/1499 [16:08<1:43:20,  5.39s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 350/1499 [16:14<1:43:26,  5.40s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 351/1499 [16:19<1:43:30,  5.41s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  23%|██▎       | 352/1499 [16:25<1:43:51,  5.43s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▎       | 353/1499 [16:30<1:43:53,  5.44s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▎       | 354/1499 [16:35<1:43:48,  5.44s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▎       | 355/1499 [16:41<1:43:57,  5.45s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▎       | 356/1499 [16:46<1:43:57,  5.46s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▍       | 357/1499 [16:52<1:44:39,  5.50s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▍       | 358/1499 [16:57<1:44:25,  5.49s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▍       | 359/1499 [17:03<1:44:03,  5.48s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▍       | 360/1499 [17:08<1:44:06,  5.48s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▍       | 361/1499 [17:14<1:44:07,  5.49s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▍       | 362/1499 [17:19<1:44:05,  5.49s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▍       | 363/1499 [17:25<1:44:18,  5.51s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▍       | 364/1499 [17:31<1:44:42,  5.54s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▍       | 365/1499 [17:36<1:45:29,  5.58s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▍       | 366/1499 [17:42<1:45:39,  5.60s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  24%|██▍       | 367/1499 [1:13:01<314:18:44, 999.58s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  25%|██▍       | 368/1499 [1:13:09<220:38:57, 702.33s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  25%|██▍       | 369/1499 [1:13:17<155:00:58, 493.86s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  25%|██▍       | 370/1499 [1:13:23<108:59:05, 347.52s/it]C:\Users\Joost\PycharmProjects\venv\lib\site-packages\sklearn\utils\_array_api.py:245: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# Feature Scoring Progress:  25%|██▍       | 371/1499 [1:13:29<76:46:11, 245.01s/it]

# %%
fig, ax = plt.subplots(1)

combined_scores.T.plot(ax=ax)
ax.legend(bbox_to_anchor=(1,1))
ax.set_xlabel('Samples')
ax.set_ylabel('feature scores')
plt.show()

# %%
cleaned_experiments = experiments.drop(columns=[l.name for l in lake_model.levers])

scores = feature_scoring.get_feature_scores_all(cleaned_experiments,results)

# %%
import seaborn as sns
cleaned_experiments = experiments.drop(columns=[l.name for l in lake_model.levers])

for policy in experiments.policy.unique():
    logical = experiments.policy == policy
    subset_results = {k:v[logical] for k,v in results.items()}
    scores = feature_scoring.get_feature_scores_all(cleaned_experiments[logical],
                                                   subset_results)
    sns.heatmap(scores, annot=True, cmap='viridis')
    plt.show()
