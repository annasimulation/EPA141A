# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from ema_workbench import (Model, RealParameter, IntegerParameter, CategoricalParameter,
                           ScalarOutcome, load_results, perform_experiments, Samplers, Policy, Scenario, HypervolumeMetric,
                           GenerationalDistanceMetric, EpsilonIndicatorMetric, InvertedGenerationalDistanceMetric,
                           SpacingMetric)
from ema_workbench.em_framework import (SequentialEvaluator, MultiprocessingEvaluator)
from ema_workbench.util import ema_logging
from ema_workbench.em_framework.optimization import (EpsNSGAII, Convergence)
from ema_workbench.analysis import parcoords
from dike_model_function import DikeNetwork
import matplotlib.pyplot as plt
from ema_workbench.em_framework.optimization import (ArchiveLogger, EpsilonProgress)
import os
from ema_workbench.em_framework.optimization import to_problem
import seaborn as sns

# Define the sum_over function
def sum_over(*args):
    numbers = []
    for entry in args:
        try:
            value = sum(entry)
        except TypeError:
            value = entry
        numbers.append(value)
    return sum(numbers)

# Define the function to get the model for the given problem formulation
def get_model_for_problem_formulation(problem_formulation_id):
    function = DikeNetwork()
    dike_model = Model("dikesnet", function=function)

    Real_uncert = {"Bmax": [30, 350], "pfail": [0, 1]}  # m and [.]
    cat_uncert_loc = {"Brate": (1.0, 1.5, 10)}
    cat_uncert = {f"discount rate {n}": (1.5, 2.5, 3.5, 4.5) for n in function.planning_steps}
    Int_uncert = {"A.0_ID flood wave shape": [0, 132]}

    uncertainties = []

    for uncert_name in cat_uncert.keys():
        categories = cat_uncert[uncert_name]
        uncertainties.append(CategoricalParameter(uncert_name, categories))

    for uncert_name in Int_uncert.keys():
        uncertainties.append(IntegerParameter(uncert_name, Int_uncert[uncert_name][0], Int_uncert[uncert_name][1]))

    dike_height_levers = []
    for dike in function.dikelist:
        for uncert_name in Real_uncert.keys():
            name = f"{dike}_{uncert_name}"
            lower, upper = Real_uncert[uncert_name]
            uncertainties.append(RealParameter(name, lower, upper))

        for uncert_name in cat_uncert_loc.keys():
            name = f"{dike}_{uncert_name}"
            categories = cat_uncert_loc[uncert_name]
            uncertainties.append(CategoricalParameter(name, categories))

        for n in function.planning_steps:
            name = f"{dike}_DikeIncrease {n}"
            dike_height_levers.append(IntegerParameter(name, 0, 10))

    dike_model.uncertainties = uncertainties

    dike_height_levers.append(IntegerParameter("EWS_DaysToThreat", 0, 4))  # days
    # Set levers: No RfR, dike heightening
    dike_model.levers = dike_height_levers

    # Define the outcomes
    outcomes = [
        ScalarOutcome('Total Costs', kind=ScalarOutcome.MINIMIZE, function=sum_over, variable_name=[
            f"{dike}_Expected Annual Damage" for dike in function.dikelist] +
                      [f"{dike}_Dike Investment Costs" for dike in function.dikelist] +
                      ["RfR Total Costs"]
        ),
        ScalarOutcome('Expected Number of Deaths', kind=ScalarOutcome.MINIMIZE, function=sum_over, variable_name=[
            f"{dike}_Expected Number of Deaths" for dike in function.dikelist]
        ),
        ScalarOutcome('Expected Annual Damage', kind=ScalarOutcome.MINIMIZE, function=sum_over, variable_name=[
            f"{dike}_Expected Annual Damage" for dike in function.dikelist]),
        ScalarOutcome('Dike Investment Costs', kind=ScalarOutcome.MINIMIZE, function=sum_over,
                      variable_name=[f"{dike}_Dike Investment Costs" for dike in function.dikelist])
    ]

    dike_model.outcomes = outcomes

    return dike_model

# Get the model for a specific problem formulation
problem_formulation_id = 6  # Change this to the desired problem formulation
dike_model = get_model_for_problem_formulation(problem_formulation_id)

# %%
# Load the optimization results
results = []
for i in range(5):
    result_df = pd.read_csv(f'output/optimization_outcomes_{i}.csv')
    results.append(result_df)

# Define the columns to plot
columns_to_plot = ['Total Costs', 'Expected Number of Deaths', 'Expected Annual Damage', 'Dike Investment Costs']
custom_column_names = ['Total costs', 'Exp num deaths', 'EAD', 'Dike inv costs']

# Ensure the columns are present in the results
present_columns = []
for col in columns_to_plot:
    if all(col in result.columns for result in results):
        present_columns.append(col)

# Define limits based on the actual range of your outcomes
limits = pd.DataFrame({
    'min': [min(result[col].min() for result in results) for col in present_columns],
    'max': [max(result[col].max() for result in results) for col in present_columns]
}, index=present_columns).T

# Rename the limits DataFrame columns for better readability
limits.columns = custom_column_names

# Create parallel axes
axes = parcoords.ParallelAxes(limits)

# Plot each result set
for i, (result, color) in enumerate(zip(results, sns.color_palette("husl", 5))):
    outcomes = result[present_columns]
    outcomes.columns = custom_column_names  # Rename the outcomes columns for plotting
    axes.plot(outcomes, color=color, label=f'results {i}')

# Invert the axis for outcomes where lower values are better
for col in custom_column_names:
    axes.invert_axis(col)

# Add legend and display the plot
axes.legend()
plt.show()

# %% [markdown]
# This graph contains all the different outcomes of the policies showing that the different scenario's have large impact on the effectiveness of the policies.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ema_workbench.em_framework.optimization import ArchiveLogger, epsilon_nondominated
from ema_workbench import MultiprocessingEvaluator
from ema_workbench.em_framework.optimization import EpsilonProgress
from ema_workbench.em_framework.optimization import to_problem, HypervolumeMetric, GenerationalDistanceMetric, EpsilonIndicatorMetric, InvertedGenerationalDistanceMetric, SpacingMetric
from dike_model_function import DikeNetwork

# Load archives
all_archives = []
for i in range(5):
    archives = ArchiveLogger.load_archives(f"./archives/{i}.tar.gz")
    for key in archives:
        if 'Unnamed: 0' in archives[key].columns:
            archives[key] = archives[key].drop('Unnamed: 0', axis=1)
    all_archives.append(archives)

# Load results from all runs
results = []
for i in range(5):
    result = pd.read_csv(f'output/optimization_policies_{i}.csv')
    results.append(result)

# Function to calculate metrics
def calculate_metrics(archives, reference_set):
    problem = to_problem(dike_model, searchover="levers")

    hv = HypervolumeMetric(reference_set, problem)
    gd = GenerationalDistanceMetric(reference_set, problem, d=1)
    ei = EpsilonIndicatorMetric(reference_set, problem)
    ig = InvertedGenerationalDistanceMetric(reference_set, problem, d=1)
    sm = SpacingMetric(problem)

    metrics = []
    for nfe, archive in archives.items():
        scores = {
            "generational_distance": gd.calculate(archive),
            "hypervolume": hv.calculate(archive),
            "epsilon_indicator": ei.calculate(archive),
            "inverted_gd": ig.calculate(archive),
            "spacing": sm.calculate(archive),
            "nfe": int(nfe),
        }
    

        # Handle infinite values
        for key in scores:
            if scores[key] == float('inf'):
                scores[key] = None

        metrics.append(scores)
    metrics = pd.DataFrame.from_dict(metrics)

    # sort metrics by number of function evaluations
    metrics.sort_values(by="nfe", inplace=True)
    return metrics

# Load convergence metrics from all runs
convergences = []
for i in range(5):
    convergence = pd.read_csv(f'output/convergence_metrics_{i}.csv')
    convergences.append(convergence)

# Define the problem and calculate the reference set
problem = to_problem(dike_model, searchover="levers")
results_concat = pd.concat(results, ignore_index=True)
reference_set = epsilon_nondominated([results_concat], epsilons=[0.1, 0.1, 0.1, 0.1], problem=problem)

# Calculate metrics for each seed
metrics_by_seed = []
for entry in all_archives:
    metrics = calculate_metrics(entry, reference_set)
    metrics_by_seed.append(metrics)

sns.set_style("white")
fig, axes = plt.subplots(nrows=6, figsize=(8, 12), sharex=True)

ax1, ax2, ax3, ax4, ax5, ax6 = axes

for metrics, convergence in zip(metrics_by_seed, convergences):
    ax1.plot(metrics.nfe, metrics.hypervolume)
    ax1.set_ylabel("hypervolume")

    ax2.plot(convergence['nfe'], convergence['epsilon_progress'])
    ax2.set_ylabel("$\epsilon$ progress")

    ax3.plot(metrics.nfe, metrics.generational_distance)
    ax3.set_ylabel("generational distance")

    ax4.plot(metrics.nfe, metrics.epsilon_indicator)
    ax4.set_ylabel("epsilon indicator")

    ax5.plot(metrics.nfe, metrics.inverted_gd)
    ax5.set_ylabel("inverted generational\ndistance")

    ax6.plot(metrics.nfe, metrics.spacing)
    ax6.set_ylabel("spacing")

ax6.set_xlabel("nfe")

sns.despine(fig)

plt.show()

# %% [markdown]
# Above the convergence of the optimization can be seen, which seems to have stabilized meaning that 100.000 runs is enough.

# %%
import pandas as pd

# Initialize an empty list to hold the dataframes
policy_dfs = []

# Loop over the indices and read each CSV file
for idx in range(5):
    df = pd.read_csv(f'output/optimization_outcomes_{idx}.csv')
    policy_dfs.append(df)

# Concatenate all dataframes into one
combined_policies_df = pd.concat(policy_dfs, ignore_index=True)

# Save the combined dataframe to a new CSV file
combined_policies_df.to_csv('combined_optimization_outcomes.csv', index=False)

# Print the first few rows of the combined dataframe to verify
#Let us now inspect options where the number of deaths is very low (expected number of deaths lower than 0.001) and the Dike investment costs are lowest
combined_policies_df_final = combined_policies_df[combined_policies_df['Expected Number of Deaths']<0.001]
combined_policies_df_final.sort_values('Dike Investment Costs', ascending=True)
# Out:
#       Total Costs  Expected Number of Deaths  Expected Annual Damage  \
# 105  1.930750e+08                   0.000977            1.844254e+07
# 111  1.849130e+08                   0.000535            9.269323e+06
# 113  1.869434e+08                   0.000509            6.878797e+06
# 109  1.908615e+08                   0.000409            5.772558e+06
# 110  1.913128e+08                   0.000244            3.731332e+06
# 112  1.913110e+08                   0.000144            2.625092e+06
# 76   1.938475e+08                   0.000000            0.000000e+00
# 121  2.054797e+08                   0.000769            1.003610e+07
# 125  2.069055e+08                   0.000782            8.861637e+06
# 115  2.061980e+08                   0.000416            7.931701e+06
# 119  2.073858e+08                   0.000726            6.648848e+06
# 117  2.085379e+08                   0.000706            6.283232e+06
# 126  2.081042e+08                   0.000372            4.544446e+06
# 120  2.074807e+08                   0.000374            2.473592e+06
# 141  2.086328e+08                   0.000354            2.107976e+06
# 124  2.081991e+08                   0.000020            3.691899e+05
# 131  2.093476e+08                   0.000000            0.000000e+00
# 229  2.310634e+08                   0.000909            3.657661e+06
# 210  2.309918e+08                   0.000816            2.464797e+06
# 209  2.974496e+08                   0.000758            4.482207e+06
# 203  2.983289e+08                   0.000745            4.240192e+06
#
#      Dike Investment Costs
# 105           1.746324e+08
# 111           1.756437e+08
# 113           1.800646e+08
# 109           1.850889e+08
# 110           1.875814e+08
# 112           1.886859e+08
# 76            1.938475e+08
# 121           1.954436e+08
# 125           1.980439e+08
# 115           1.982663e+08
# 119           2.007370e+08
# 117           2.022547e+08
# 126           2.035597e+08
# 120           2.050072e+08
# 141           2.065248e+08
# 124           2.078299e+08
# 131           2.093476e+08
# 229           2.274057e+08
# 210           2.285270e+08
# 209           2.929673e+08
# 203           2.940887e+08

# %%
# Function to calculate SNR metric
def snr(data, direction):
    mean = np.mean(data)
    std = np.std(data)

    if direction==ScalarOutcome.MINIMIZE:
        return mean*std
    else:
        return mean/std

# %%
# Initialize an empty list to hold the dataframes
policy_dfs = []

# Loop over the indices and read each CSV file
for idx in range(5):
    df = pd.read_csv(f'output/optimization_outcomes_{idx}.csv')
    # Debug: print the first few rows of the dataframe
    
    # Add a column informing of original scenario
    df['Original Scenario'] = f'reference_{idx}'
    # Add a policy column
    df['policy'] = df.index.to_series().apply(lambda x: f'policy_{idx}_{x}')
    policy_dfs.append(df)

# Concatenate all dataframes into one
combined_policies_df = pd.concat(policy_dfs, ignore_index=True)



# Save the combined dataframe to a new CSV file
combined_policies_df.to_csv('output/combined_optimization_outcomes.csv', index=False)

# Create two dictionaries separating entries by scenarios
experiments_by_scenario = {}
outcomes_by_scenario = {}
scenarios = np.unique(combined_policies_df['Original Scenario'])

for scenario in scenarios:
    experiments_by_scenario[scenario] = combined_policies_df[combined_policies_df['Original Scenario'] == scenario]
    

    
    indices = list(experiments_by_scenario[scenario].index)
    
    outcomes_by_scenario[scenario] = {}
    for key in combined_policies_df.columns:
        if key not in ['Original Scenario']:
            outcomes_by_scenario[scenario][key] = []

            for i in indices:
                outcomes_by_scenario[scenario][key].append(combined_policies_df.at[i, key])

# Debug: print the contents of outcomes_by_scenario for one scenario
for scenario, outcomes in outcomes_by_scenario.items():
    for key, values in outcomes.items():
        print(f'{key}: {values[:5]}')  # Print the first 5 values for brevity
    break  # Only print for one scenario to avoid too much output
# Out:
# Total Costs: [276588023.65475965, 319361604.5985232, 269797006.7966592, 1420591043.3405864, 325503631.0370579]
# Expected Number of Deaths: [0.003362084653303, 0.0013931995995723, 0.0071585590336169, 0.1227594652989065, 0.0167857456316171]
# Expected Annual Damage: [16644196.113021009, 10317619.900488809, 68461149.02230066, 1335219739.4349172, 137152377.7568998]
# Dike Investment Costs: [259943827.54173863, 309043984.6980344, 201335857.7743585, 85371303.9056692, 188351253.28015807]
# policy: ['policy_0_0', 'policy_0_1', 'policy_0_2', 'policy_0_3', 'policy_0_4']

# %%
# Assuming model and snr are already defined
model = get_model_for_problem_formulation(6)
outcomes_of_interest = ['Total Costs', 'Expected Number of Deaths', 'Expected Annual Damage', 'Dike Investment Costs']

# Calculate SNR scores per policy per outcome and write it to a dictionary organized by scenario
snr_scores = {}
for scenario in scenarios:
    experiment_snr_scores = {}
    for policy in experiments_by_scenario[scenario]['policy']:
        scores = {}

        logical = experiments_by_scenario[scenario]['policy'] == policy

        for outcome in model.outcomes:
            if outcome.name in outcomes_of_interest:
                value = np.array(outcomes_by_scenario[scenario][outcome.name])[logical]
                sn_ratio = snr(value, outcome.kind)
                scores[outcome.name] = sn_ratio
                # Debug: print the outcome values and SNR
                print(f"Scenario: {scenario}, Policy: {policy}, Outcome: {outcome.name}, Values: {value}, SNR: {sn_ratio}")
        experiment_snr_scores[policy] = scores
    df = pd.DataFrame.from_dict(experiment_snr_scores).T
    snr_scores[scenario] = df

# Debug: print the SNR scores for one scenario
for scenario, df in snr_scores.items():
    print(f"Scenario: {scenario}")
    print(df.head())
    break
# Out:
# Scenario: reference_0, Policy: policy_0_0, Outcome: Total Costs, Values: [2.76588024e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_0, Outcome: Expected Number of Deaths, Values: [0.00336208], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_0, Outcome: Expected Annual Damage, Values: [16644196.11302101], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_0, Outcome: Dike Investment Costs, Values: [2.59943828e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_1, Outcome: Total Costs, Values: [3.19361605e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_1, Outcome: Expected Number of Deaths, Values: [0.0013932], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_1, Outcome: Expected Annual Damage, Values: [10317619.90048881], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_1, Outcome: Dike Investment Costs, Values: [3.09043985e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_2, Outcome: Total Costs, Values: [2.69797007e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_2, Outcome: Expected Number of Deaths, Values: [0.00715856], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_2, Outcome: Expected Annual Damage, Values: [68461149.02230066], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_2, Outcome: Dike Investment Costs, Values: [2.01335858e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_3, Outcome: Total Costs, Values: [1.42059104e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_3, Outcome: Expected Number of Deaths, Values: [0.12275947], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_3, Outcome: Expected Annual Damage, Values: [1.33521974e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_3, Outcome: Dike Investment Costs, Values: [85371303.9056692], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_4, Outcome: Total Costs, Values: [3.25503631e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_4, Outcome: Expected Number of Deaths, Values: [0.01678575], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_4, Outcome: Expected Annual Damage, Values: [1.37152378e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_4, Outcome: Dike Investment Costs, Values: [1.88351253e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_5, Outcome: Total Costs, Values: [3.49746008e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_5, Outcome: Expected Number of Deaths, Values: [0.01412554], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_5, Outcome: Expected Annual Damage, Values: [1.61855317e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_5, Outcome: Dike Investment Costs, Values: [1.87890691e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_6, Outcome: Total Costs, Values: [3.67191139e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_6, Outcome: Expected Number of Deaths, Values: [0.50594057], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_6, Outcome: Expected Annual Damage, Values: [3.61793889e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_6, Outcome: Dike Investment Costs, Values: [53972506.18695759], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_7, Outcome: Total Costs, Values: [7.40530472e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_7, Outcome: Expected Number of Deaths, Values: [0.0528538], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_7, Outcome: Expected Annual Damage, Values: [6.10618262e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_7, Outcome: Dike Investment Costs, Values: [1.29912209e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_8, Outcome: Total Costs, Values: [2.97677402e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_8, Outcome: Expected Number of Deaths, Values: [0.00675945], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_8, Outcome: Expected Annual Damage, Values: [96772445.5690298], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_8, Outcome: Dike Investment Costs, Values: [2.00904956e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_9, Outcome: Total Costs, Values: [1.70317416e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_9, Outcome: Expected Number of Deaths, Values: [0.13586867], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_9, Outcome: Expected Annual Damage, Values: [1.62666109e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_9, Outcome: Dike Investment Costs, Values: [76513067.39269884], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_10, Outcome: Total Costs, Values: [3.00377157e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_10, Outcome: Expected Number of Deaths, Values: [0.01131877], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_10, Outcome: Expected Annual Damage, Values: [1.04554972e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_10, Outcome: Dike Investment Costs, Values: [1.95822185e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_11, Outcome: Total Costs, Values: [3.81065653e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_11, Outcome: Expected Number of Deaths, Values: [0.01584476], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_11, Outcome: Expected Annual Damage, Values: [1.99495763e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_11, Outcome: Dike Investment Costs, Values: [1.8156989e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_12, Outcome: Total Costs, Values: [1.76985768e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_12, Outcome: Expected Number of Deaths, Values: [0.14824848], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_12, Outcome: Expected Annual Damage, Values: [1.69616738e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_12, Outcome: Dike Investment Costs, Values: [73690303.3730879], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_13, Outcome: Total Costs, Values: [1.34631871e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_13, Outcome: Expected Number of Deaths, Values: [0.10737837], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_13, Outcome: Expected Annual Damage, Values: [1.23308743e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_13, Outcome: Dike Investment Costs, Values: [1.13231282e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_14, Outcome: Total Costs, Values: [5.86844372e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_14, Outcome: Expected Number of Deaths, Values: [0.03664663], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_14, Outcome: Expected Annual Damage, Values: [4.23315598e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_14, Outcome: Dike Investment Costs, Values: [1.63528774e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_15, Outcome: Total Costs, Values: [1.6484634e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_15, Outcome: Expected Number of Deaths, Values: [0.1598557], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_15, Outcome: Expected Annual Damage, Values: [1.57181705e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_15, Outcome: Dike Investment Costs, Values: [76646345.09206319], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_16, Outcome: Total Costs, Values: [2.54614496e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_16, Outcome: Expected Number of Deaths, Values: [0.00630928], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_16, Outcome: Expected Annual Damage, Values: [52157310.51301646], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_16, Outcome: Dike Investment Costs, Values: [2.02457185e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_17, Outcome: Total Costs, Values: [3.63701404e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_17, Outcome: Expected Number of Deaths, Values: [0.01366922], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_17, Outcome: Expected Annual Damage, Values: [1.78037529e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_17, Outcome: Dike Investment Costs, Values: [1.85663875e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_18, Outcome: Total Costs, Values: [1.35405342e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_18, Outcome: Expected Number of Deaths, Values: [0.11033915], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_18, Outcome: Expected Annual Damage, Values: [1.26585935e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_18, Outcome: Dike Investment Costs, Values: [88194067.92528014], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_19, Outcome: Total Costs, Values: [3.36388427e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_19, Outcome: Expected Number of Deaths, Values: [0.01093441], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_19, Outcome: Expected Annual Damage, Values: [1.48183536e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_19, Outcome: Dike Investment Costs, Values: [1.88204891e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_20, Outcome: Total Costs, Values: [2.49120445e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_20, Outcome: Expected Number of Deaths, Values: [0.003978], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_20, Outcome: Expected Annual Damage, Values: [39757731.66709648], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_20, Outcome: Dike Investment Costs, Values: [2.09362714e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_21, Outcome: Total Costs, Values: [6.16765794e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_21, Outcome: Expected Number of Deaths, Values: [0.04266467], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_21, Outcome: Expected Annual Damage, Values: [4.56300496e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_21, Outcome: Dike Investment Costs, Values: [1.60465297e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_22, Outcome: Total Costs, Values: [1.49214658e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_22, Outcome: Expected Number of Deaths, Values: [0.12846406], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_22, Outcome: Expected Annual Damage, Values: [1.41289983e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_22, Outcome: Dike Investment Costs, Values: [79246745.68016584], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_23, Outcome: Total Costs, Values: [3.82397398e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_23, Outcome: Expected Number of Deaths, Values: [0.01571182], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_23, Outcome: Expected Annual Damage, Values: [1.98054212e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_23, Outcome: Dike Investment Costs, Values: [1.84343187e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_24, Outcome: Total Costs, Values: [4.7892161e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_24, Outcome: Expected Number of Deaths, Values: [0.02670097], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_24, Outcome: Expected Annual Damage, Values: [3.04026995e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_24, Outcome: Dike Investment Costs, Values: [1.74894615e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_25, Outcome: Total Costs, Values: [1.07443729e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_25, Outcome: Expected Number of Deaths, Values: [0.10082876], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_25, Outcome: Expected Annual Damage, Values: [9.52372124e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_25, Outcome: Dike Investment Costs, Values: [1.22065161e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_26, Outcome: Total Costs, Values: [4.07146531e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_26, Outcome: Expected Number of Deaths, Values: [0.02093878], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_26, Outcome: Expected Annual Damage, Values: [2.26127358e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_26, Outcome: Dike Investment Costs, Values: [1.81019173e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_27, Outcome: Total Costs, Values: [5.17180302e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_27, Outcome: Expected Number of Deaths, Values: [0.03412966], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_27, Outcome: Expected Annual Damage, Values: [3.4804943e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_27, Outcome: Dike Investment Costs, Values: [1.69130871e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_28, Outcome: Total Costs, Values: [4.52840733e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_28, Outcome: Expected Number of Deaths, Values: [0.02160694], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_28, Outcome: Expected Annual Damage, Values: [2.77395401e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_28, Outcome: Dike Investment Costs, Values: [1.75445332e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_29, Outcome: Total Costs, Values: [9.51445939e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_29, Outcome: Expected Number of Deaths, Values: [0.07263592], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_29, Outcome: Expected Annual Damage, Values: [8.26558014e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_29, Outcome: Dike Investment Costs, Values: [1.24887925e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_30, Outcome: Total Costs, Values: [4.77589865e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_30, Outcome: Expected Number of Deaths, Values: [0.0268339], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_30, Outcome: Expected Annual Damage, Values: [3.05468546e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_30, Outcome: Dike Investment Costs, Values: [1.72121319e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_31, Outcome: Total Costs, Values: [3.05068782e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_31, Outcome: Expected Number of Deaths, Values: [0.00921519], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_31, Outcome: Expected Annual Damage, Values: [1.10543091e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_31, Outcome: Dike Investment Costs, Values: [1.94525691e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_32, Outcome: Total Costs, Values: [3.74346693e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_32, Outcome: Expected Number of Deaths, Values: [0.51164516], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_32, Outcome: Expected Annual Damage, Values: [3.69561898e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_32, Outcome: Dike Investment Costs, Values: [47847947.96145424], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_33, Outcome: Total Costs, Values: [4.05814786e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_33, Outcome: Expected Number of Deaths, Values: [0.02107172], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_33, Outcome: Expected Annual Damage, Values: [2.27568909e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_33, Outcome: Dike Investment Costs, Values: [1.78245877e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_34, Outcome: Total Costs, Values: [6.6875595e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_34, Outcome: Expected Number of Deaths, Values: [0.04709164], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_34, Outcome: Expected Annual Damage, Values: [5.32719183e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_34, Outcome: Dike Investment Costs, Values: [1.36036767e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_35, Outcome: Total Costs, Values: [3.7449514e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_35, Outcome: Expected Number of Deaths, Values: [0.0193525], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_35, Outcome: Expected Annual Damage, Values: [1.89928463e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_35, Outcome: Dike Investment Costs, Values: [1.84566677e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_36, Outcome: Total Costs, Values: [1.42558724e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_36, Outcome: Expected Number of Deaths, Values: [0.11608793], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_36, Outcome: Expected Annual Damage, Values: [1.34351773e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_36, Outcome: Dike Investment Costs, Values: [82069509.69977678], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_37, Outcome: Total Costs, Values: [5.59033402e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_37, Outcome: Expected Number of Deaths, Values: [0.03387377], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_37, Outcome: Expected Annual Damage, Values: [3.92963612e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_37, Outcome: Dike Investment Costs, Values: [1.66069789e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_38, Outcome: Total Costs, Values: [5.88954823e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_38, Outcome: Expected Number of Deaths, Values: [0.03989181], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_38, Outcome: Expected Annual Damage, Values: [4.2594851e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_38, Outcome: Dike Investment Costs, Values: [1.63006313e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_39, Outcome: Total Costs, Values: [3.22345707e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_39, Outcome: Expected Number of Deaths, Values: [0.01656813], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_39, Outcome: Expected Annual Damage, Values: [1.32873127e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_39, Outcome: Dike Investment Costs, Values: [1.89472581e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_40, Outcome: Total Costs, Values: [5.04902842e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_40, Outcome: Expected Number of Deaths, Values: [0.02956872], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_40, Outcome: Expected Annual Damage, Values: [3.35322539e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_40, Outcome: Dike Investment Costs, Values: [1.69580303e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_41, Outcome: Total Costs, Values: [5.44991272e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_41, Outcome: Expected Number of Deaths, Values: [0.03690252], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_41, Outcome: Expected Annual Damage, Values: [3.78401417e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_41, Outcome: Dike Investment Costs, Values: [1.66589856e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_42, Outcome: Total Costs, Values: [2.96345657e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_42, Outcome: Expected Number of Deaths, Values: [0.00689238], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_42, Outcome: Expected Annual Damage, Values: [98213996.5907165], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_42, Outcome: Dike Investment Costs, Values: [1.9813166e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_43, Outcome: Total Costs, Values: [4.33127763e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_43, Outcome: Expected Number of Deaths, Values: [0.02380654], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_43, Outcome: Expected Annual Damage, Values: [2.57422902e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_43, Outcome: Dike Investment Costs, Values: [1.75704861e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_44, Outcome: Total Costs, Values: [3.72342528e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_44, Outcome: Expected Number of Deaths, Values: [0.01352195], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_44, Outcome: Expected Annual Damage, Values: [1.87166669e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_44, Outcome: Dike Investment Costs, Values: [1.85175859e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_45, Outcome: Total Costs, Values: [1.22903286e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_45, Outcome: Expected Number of Deaths, Values: [0.09241666], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_45, Outcome: Expected Annual Damage, Values: [1.10970137e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_45, Outcome: Dike Investment Costs, Values: [1.19331483e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_46, Outcome: Total Costs, Values: [6.83078162e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_46, Outcome: Expected Number of Deaths, Values: [0.04519355], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_46, Outcome: Expected Annual Damage, Values: [5.25587723e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_46, Outcome: Dike Investment Costs, Values: [1.57490439e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_47, Outcome: Total Costs, Values: [3.19743176e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_47, Outcome: Expected Number of Deaths, Values: [0.38982438], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_47, Outcome: Expected Annual Damage, Values: [3.12873687e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_47, Outcome: Dike Investment Costs, Values: [68694885.19668272], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_48, Outcome: Total Costs, Values: [2.50306675e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_48, Outcome: Expected Number of Deaths, Values: [0.00397495], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_48, Outcome: Expected Annual Damage, Values: [39702173.34765121], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_48, Outcome: Dike Investment Costs, Values: [2.10604501e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_49, Outcome: Total Costs, Values: [1.03284197e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_49, Outcome: Expected Number of Deaths, Values: [0.0738786], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_49, Outcome: Expected Annual Damage, Values: [9.084862e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_49, Outcome: Dike Investment Costs, Values: [1.24355767e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_50, Outcome: Total Costs, Values: [2.83429305e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_50, Outcome: Expected Number of Deaths, Values: [0.00273017], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_50, Outcome: Expected Annual Damage, Values: [10851041.50433448], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_50, Outcome: Dike Investment Costs, Values: [2.72578264e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_51, Outcome: Total Costs, Values: [2.75216032e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_51, Outcome: Expected Number of Deaths, Values: [0.00409375], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_51, Outcome: Expected Annual Damage, Values: [28935599.04607484], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_51, Outcome: Dike Investment Costs, Values: [2.46280433e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_52, Outcome: Total Costs, Values: [3.93122259e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_52, Outcome: Expected Number of Deaths, Values: [0.27994385], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_52, Outcome: Expected Annual Damage, Values: [3.90481921e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_52, Outcome: Dike Investment Costs, Values: [26403379.54230644], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_53, Outcome: Total Costs, Values: [1.94102112e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_53, Outcome: Expected Number of Deaths, Values: [0.18086999], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_53, Outcome: Expected Annual Damage, Values: [1.86993121e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_53, Outcome: Dike Investment Costs, Values: [71089902.78498524], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_54, Outcome: Total Costs, Values: [2.81354022e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_54, Outcome: Expected Number of Deaths, Values: [0.00291032], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_54, Outcome: Expected Annual Damage, Values: [11522845.75420919], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_54, Outcome: Dike Investment Costs, Values: [2.69831176e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_55, Outcome: Total Costs, Values: [2.84439474e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_55, Outcome: Expected Number of Deaths, Values: [0.00270263], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_55, Outcome: Expected Annual Damage, Values: [10343524.01885029], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_55, Outcome: Dike Investment Costs, Values: [2.7409595e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_56, Outcome: Total Costs, Values: [3.52793274e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_56, Outcome: Expected Number of Deaths, Values: [0.00132498], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_56, Outcome: Expected Annual Damage, Values: [9328357.84980877], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_56, Outcome: Dike Investment Costs, Values: [3.43464916e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_57, Outcome: Total Costs, Values: [2.79071673e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_57, Outcome: Expected Number of Deaths, Values: [0.00386691], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_57, Outcome: Expected Annual Damage, Values: [23248509.2880445], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_57, Outcome: Dike Investment Costs, Values: [2.55823164e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_58, Outcome: Total Costs, Values: [2.82434692e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_58, Outcome: Expected Number of Deaths, Values: [0.00293919], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_58, Outcome: Expected Annual Damage, Values: [15149845.63223044], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_58, Outcome: Dike Investment Costs, Values: [2.67284846e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_59, Outcome: Total Costs, Values: [2.81074238e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_59, Outcome: Expected Number of Deaths, Values: [0.00317239], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_59, Outcome: Expected Annual Damage, Values: [16536479.40815738], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_59, Outcome: Dike Investment Costs, Values: [2.64537759e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_60, Outcome: Total Costs, Values: [4.33471752e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_60, Outcome: Expected Number of Deaths, Values: [0.02990149], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_60, Outcome: Expected Annual Damage, Values: [2.57008801e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_60, Outcome: Dike Investment Costs, Values: [1.76462952e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_61, Outcome: Total Costs, Values: [6.13499458e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_61, Outcome: Expected Number of Deaths, Values: [0.64820815], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_61, Outcome: Expected Annual Damage, Values: [6.13499458e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_61, Outcome: Dike Investment Costs, Values: [0.], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_62, Outcome: Total Costs, Values: [2.76126244e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_62, Outcome: Expected Number of Deaths, Values: [0.00487186], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_62, Outcome: Expected Annual Damage, Values: [31862037.74578026], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_62, Outcome: Dike Investment Costs, Values: [2.44264206e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_63, Outcome: Total Costs, Values: [3.80424047e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_63, Outcome: Expected Number of Deaths, Values: [0.25845345], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_63, Outcome: Expected Annual Damage, Values: [3.77544208e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_63, Outcome: Dike Investment Costs, Values: [28798397.13060894], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_64, Outcome: Total Costs, Values: [2.82610333e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_64, Outcome: Expected Number of Deaths, Values: [0.00289619], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_64, Outcome: Expected Annual Damage, Values: [11261471.00241856], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_64, Outcome: Dike Investment Costs, Values: [2.71348862e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_65, Outcome: Total Costs, Values: [2.75240628e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_65, Outcome: Expected Number of Deaths, Values: [0.00359632], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_65, Outcome: Expected Annual Damage, Values: [18043887.66178513], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_65, Outcome: Dike Investment Costs, Values: [2.5719674e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_66, Outcome: Total Costs, Values: [3.23212731e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_66, Outcome: Expected Number of Deaths, Values: [0.00136567], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_66, Outcome: Expected Annual Damage, Values: [9810102.41500462], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_66, Outcome: Dike Investment Costs, Values: [3.13402629e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_67, Outcome: Total Costs, Values: [4.93814312e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_67, Outcome: Expected Number of Deaths, Values: [0.44691399], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_67, Outcome: Expected Annual Damage, Values: [4.9159753e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_67, Outcome: Dike Investment Costs, Values: [22167818.19880376], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_68, Outcome: Total Costs, Values: [3.73790671e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_68, Outcome: Expected Number of Deaths, Values: [0.24966241], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_68, Outcome: Expected Annual Damage, Values: [3.66826279e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_68, Outcome: Dike Investment Costs, Values: [69643919.67047566], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_69, Outcome: Total Costs, Values: [3.77111767e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_69, Outcome: Expected Number of Deaths, Values: [0.25586286], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_69, Outcome: Expected Annual Damage, Values: [3.70407415e+09], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_69, Outcome: Dike Investment Costs, Values: [67043519.082373], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_70, Outcome: Total Costs, Values: [5.06368159e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_70, Outcome: Expected Number of Deaths, Values: [0.03566367], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_70, Outcome: Expected Annual Damage, Values: [3.34908438e+08], SNR: 0.0
# Scenario: reference_0, Policy: policy_0_70, Outcome: Dike Investment Costs, Values: [1.71459721e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_0, Outcome: Total Costs, Values: [5.43123419e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_0, Outcome: Expected Number of Deaths, Values: [0.03642369], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_0, Outcome: Expected Annual Damage, Values: [4.45154301e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_0, Outcome: Dike Investment Costs, Values: [97969117.67031184], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_1, Outcome: Total Costs, Values: [4.35622719e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_1, Outcome: Expected Number of Deaths, Values: [0.2597976], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_1, Outcome: Expected Annual Damage, Values: [4.32982381e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_1, Outcome: Dike Investment Costs, Values: [26403379.54230644], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_2, Outcome: Total Costs, Values: [1.00886812e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_2, Outcome: Expected Number of Deaths, Values: [0.14733365], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_2, Outcome: Expected Annual Damage, Values: [9.48150809e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_2, Outcome: Dike Investment Costs, Values: [60717312.84309486], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_3, Outcome: Total Costs, Values: [1.70117363e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_3, Outcome: Expected Number of Deaths, Values: [0.00480072], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_3, Outcome: Expected Annual Damage, Values: [42287473.53603357], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_3, Outcome: Dike Investment Costs, Values: [1.27829889e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_4, Outcome: Total Costs, Values: [6.18804439e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_4, Outcome: Expected Number of Deaths, Values: [0.049805], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_4, Outcome: Expected Annual Damage, Values: [5.33889094e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_4, Outcome: Dike Investment Costs, Values: [84915345.29445624], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_5, Outcome: Total Costs, Values: [1.93847519e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_5, Outcome: Expected Number of Deaths, Values: [0.], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_5, Outcome: Expected Annual Damage, Values: [0.], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_5, Outcome: Dike Investment Costs, Values: [1.93847519e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_6, Outcome: Total Costs, Values: [5.36223421e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_6, Outcome: Expected Number of Deaths, Values: [0.03548874], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_6, Outcome: Expected Annual Damage, Values: [4.46707711e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_6, Outcome: Dike Investment Costs, Values: [89515709.9737038], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_7, Outcome: Total Costs, Values: [5.48418698e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_7, Outcome: Expected Number of Deaths, Values: [0.03790994], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_7, Outcome: Expected Annual Damage, Values: [4.61298005e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_7, Outcome: Dike Investment Costs, Values: [87120692.38540131], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_8, Outcome: Total Costs, Values: [4.51426426e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_8, Outcome: Expected Number of Deaths, Values: [0.30822853], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_8, Outcome: Expected Annual Damage, Values: [4.51426426e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_8, Outcome: Dike Investment Costs, Values: [0.], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_9, Outcome: Total Costs, Values: [6.31467462e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_9, Outcome: Expected Number of Deaths, Values: [0.04369555], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_9, Outcome: Expected Annual Damage, Values: [5.51091576e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_9, Outcome: Dike Investment Costs, Values: [80375885.72926402], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_10, Outcome: Total Costs, Values: [1.68967825e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_10, Outcome: Expected Number of Deaths, Values: [0.00468519], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_10, Outcome: Expected Annual Damage, Values: [40016608.0223056], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_10, Outcome: Dike Investment Costs, Values: [1.28951217e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_11, Outcome: Total Costs, Values: [1.56772547e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_11, Outcome: Expected Number of Deaths, Values: [0.00226399], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_11, Outcome: Expected Annual Damage, Values: [25426313.26804934], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_11, Outcome: Dike Investment Costs, Values: [1.31346234e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_12, Outcome: Total Costs, Values: [1.09191689e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_12, Outcome: Expected Number of Deaths, Values: [0.15311927], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_12, Outcome: Expected Annual Damage, Values: [1.03794438e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_12, Outcome: Dike Investment Costs, Values: [53972506.18695759], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_13, Outcome: Total Costs, Values: [7.01853203e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_13, Outcome: Expected Number of Deaths, Values: [0.05559062], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_13, Outcome: Expected Annual Damage, Values: [6.23682665e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_13, Outcome: Dike Investment Costs, Values: [78170538.63831897], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_14, Outcome: Total Costs, Values: [1.83428099e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_14, Outcome: Expected Number of Deaths, Values: [0.00590946], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_14, Outcome: Expected Annual Damage, Values: [65955880.46932883], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_14, Outcome: Dike Investment Costs, Values: [1.17472218e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_15, Outcome: Total Costs, Values: [4.39921081e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_15, Outcome: Expected Number of Deaths, Values: [0.26753146], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_15, Outcome: Expected Annual Damage, Values: [4.37704299e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_15, Outcome: Dike Investment Costs, Values: [22167818.19880376], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_16, Outcome: Total Costs, Values: [1.71232822e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_16, Outcome: Expected Number of Deaths, Values: [0.00348827], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_16, Outcome: Expected Annual Damage, Values: [51365585.71507257], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_16, Outcome: Dike Investment Costs, Values: [1.19867236e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_17, Outcome: Total Costs, Values: [6.19272185e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_17, Outcome: Expected Number of Deaths, Values: [0.04127435], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_17, Outcome: Expected Annual Damage, Values: [5.36501282e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_17, Outcome: Dike Investment Costs, Values: [82770903.31756654], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_18, Outcome: Total Costs, Values: [9.13520722e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_18, Outcome: Expected Number of Deaths, Values: [0.0593571], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_18, Outcome: Expected Annual Damage, Values: [8.39269395e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_18, Outcome: Dike Investment Costs, Values: [74251327.50376067], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_19, Outcome: Total Costs, Values: [9.56301576e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_19, Outcome: Expected Number of Deaths, Values: [0.06708556], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_19, Outcome: Expected Annual Damage, Values: [8.8628581e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_19, Outcome: Dike Investment Costs, Values: [70015766.160258], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_20, Outcome: Total Costs, Values: [4.45256041e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_20, Outcome: Expected Number of Deaths, Values: [0.2768255], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_20, Outcome: Expected Annual Damage, Values: [4.43226112e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_20, Outcome: Dike Investment Costs, Values: [20299287.62732069], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_21, Outcome: Total Costs, Values: [2.54281586e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_21, Outcome: Expected Number of Deaths, Values: [0.00927388], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_21, Outcome: Expected Annual Damage, Values: [1.41159157e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_21, Outcome: Dike Investment Costs, Values: [1.13122429e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_22, Outcome: Total Costs, Values: [2.40998649e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_22, Outcome: Expected Number of Deaths, Values: [0.01087558], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_22, Outcome: Expected Annual Damage, Values: [1.26299727e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_22, Outcome: Dike Investment Costs, Values: [1.14698922e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_23, Outcome: Total Costs, Values: [7.51705307e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_23, Outcome: Expected Number of Deaths, Values: [0.06406293], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_23, Outcome: Expected Annual Damage, Values: [6.75564982e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_23, Outcome: Dike Investment Costs, Values: [76140324.38576135], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_24, Outcome: Total Costs, Values: [2.28803372e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_24, Outcome: Expected Number of Deaths, Values: [0.00845439], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_24, Outcome: Expected Annual Damage, Values: [1.11709432e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_24, Outcome: Dike Investment Costs, Values: [1.1709394e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_25, Outcome: Total Costs, Values: [3.24047413e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_25, Outcome: Expected Number of Deaths, Values: [0.0166612], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_25, Outcome: Expected Annual Damage, Values: [2.16093298e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_25, Outcome: Dike Investment Costs, Values: [1.07954116e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_26, Outcome: Total Costs, Values: [2.66476863e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_26, Outcome: Expected Number of Deaths, Values: [0.01169508], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_26, Outcome: Expected Annual Damage, Values: [1.55749451e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_26, Outcome: Dike Investment Costs, Values: [1.10727412e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_27, Outcome: Total Costs, Values: [1.00941929e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_27, Outcome: Expected Number of Deaths, Values: [0.07897792], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_27, Outcome: Expected Annual Damage, Values: [9.41272051e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_27, Outcome: Dike Investment Costs, Values: [68147235.58877492], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_28, Outcome: Total Costs, Values: [7.74477484e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_28, Outcome: Expected Number of Deaths, Values: [0.07137837], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_28, Outcome: Expected Annual Damage, Values: [7.0020569e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_28, Outcome: Dike Investment Costs, Values: [74271793.81427827], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_29, Outcome: Total Costs, Values: [3.11852136e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_29, Outcome: Expected Number of Deaths, Values: [0.01424], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_29, Outcome: Expected Annual Damage, Values: [2.01503003e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_29, Outcome: Dike Investment Costs, Values: [1.10349133e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_30, Outcome: Total Costs, Values: [3.86714708e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_30, Outcome: Expected Number of Deaths, Values: [0.03206246], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_30, Outcome: Expected Annual Damage, Values: [2.80222857e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_30, Outcome: Dike Investment Costs, Values: [1.0649185e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_31, Outcome: Total Costs, Values: [3.94433155e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_31, Outcome: Expected Number of Deaths, Values: [0.02855627], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_31, Outcome: Expected Annual Damage, Values: [2.88684386e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_31, Outcome: Dike Investment Costs, Values: [1.05748769e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_32, Outcome: Total Costs, Values: [1.40977883e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_32, Outcome: Expected Number of Deaths, Values: [0.17199603], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_32, Outcome: Expected Annual Damage, Values: [1.36193089e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_32, Outcome: Dike Investment Costs, Values: [47847947.96145424], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_33, Outcome: Total Costs, Values: [4.31770461e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_33, Outcome: Expected Number of Deaths, Values: [0.04159416], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_33, Outcome: Expected Annual Damage, Values: [3.29920437e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_33, Outcome: Dike Investment Costs, Values: [1.01850024e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_34, Outcome: Total Costs, Values: [1.93074988e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_34, Outcome: Expected Number of Deaths, Values: [0.00097731], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_34, Outcome: Expected Annual Damage, Values: [18442544.91278544], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_34, Outcome: Dike Investment Costs, Values: [1.74632443e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_35, Outcome: Total Costs, Values: [4.32059078e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_35, Outcome: Expected Number of Deaths, Values: [0.25923647], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_35, Outcome: Expected Annual Damage, Values: [4.27338574e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_35, Outcome: Dike Investment Costs, Values: [47205032.28497748], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_36, Outcome: Total Costs, Values: [1.57922086e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_36, Outcome: Expected Number of Deaths, Values: [0.00237952], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_36, Outcome: Expected Annual Damage, Values: [27697178.78177731], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_36, Outcome: Dike Investment Costs, Values: [1.30224907e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_37, Outcome: Total Costs, Values: [4.35232494e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_37, Outcome: Expected Number of Deaths, Values: [0.26678761], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_37, Outcome: Expected Annual Damage, Values: [4.30698844e+09], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_37, Outcome: Dike Investment Costs, Values: [45336501.71349442], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_38, Outcome: Total Costs, Values: [1.90861451e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_38, Outcome: Expected Number of Deaths, Values: [0.0004089], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_38, Outcome: Expected Annual Damage, Values: [5772557.62222081], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_38, Outcome: Dike Investment Costs, Values: [1.85088894e+08], SNR: 0.0
# Scenario: reference_1, Policy: policy_1_39, Outcome: Total Costs, Values: [1.91312779e+08], SNR: 0.0
# ...
# Scenario: reference_4, Policy: policy_4_8, Outcome: Total Costs, Values: [2.23793876e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_8, Outcome: Expected Number of Deaths, Values: [0.00110296], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_8, Outcome: Expected Annual Damage, Values: [4929652.0743533], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_8, Outcome: Dike Investment Costs, Values: [2.18864224e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_9, Outcome: Total Costs, Values: [2.01373431e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_9, Outcome: Expected Number of Deaths, Values: [0.00267449], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_9, Outcome: Expected Annual Damage, Values: [10914792.28357359], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_9, Outcome: Dike Investment Costs, Values: [1.90458639e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_10, Outcome: Total Costs, Values: [2.19670829e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_10, Outcome: Expected Number of Deaths, Values: [0.001376], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_10, Outcome: Expected Annual Damage, Values: [7551410.96160569], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_10, Outcome: Dike Investment Costs, Values: [2.12119418e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_11, Outcome: Total Costs, Values: [1.49221824e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_11, Outcome: Expected Number of Deaths, Values: [0.00650884], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_11, Outcome: Expected Annual Damage, Values: [48319465.74958535], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_11, Outcome: Dike Investment Costs, Values: [1.00902358e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_12, Outcome: Total Costs, Values: [1.98154742e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_12, Outcome: Expected Number of Deaths, Values: [0.00292937], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_12, Outcome: Expected Annual Damage, Values: [13319582.35064042], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_12, Outcome: Dike Investment Costs, Values: [1.8483516e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_13, Outcome: Total Costs, Values: [2.01313291e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_13, Outcome: Expected Number of Deaths, Values: [0.00273959], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_13, Outcome: Expected Annual Damage, Values: [12083584.83615752], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_13, Outcome: Dike Investment Costs, Values: [1.89229706e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_14, Outcome: Total Costs, Values: [1.46253179e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_14, Outcome: Expected Number of Deaths, Values: [0.00675307], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_14, Outcome: Expected Annual Damage, Values: [51671621.19215017], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_14, Outcome: Dike Investment Costs, Values: [94581557.55753475], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_15, Outcome: Total Costs, Values: [2.61884079e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_15, Outcome: Expected Number of Deaths, Values: [0.24056326], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_15, Outcome: Expected Annual Damage, Values: [2.57191094e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_15, Outcome: Dike Investment Costs, Values: [46929851.6802434], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_16, Outcome: Total Costs, Values: [4.5452777e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_16, Outcome: Expected Number of Deaths, Values: [0.08086637], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_16, Outcome: Expected Annual Damage, Values: [3.75281024e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_16, Outcome: Dike Investment Costs, Values: [79246745.68016584], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_17, Outcome: Total Costs, Values: [1.91481017e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_17, Outcome: Expected Number of Deaths, Values: [0.00224414], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_17, Outcome: Expected Annual Damage, Values: [15934267.9401281], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_17, Outcome: Dike Investment Costs, Values: [1.75546749e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_18, Outcome: Total Costs, Values: [1.46101696e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_18, Outcome: Expected Number of Deaths, Values: [0.24716178], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_18, Outcome: Expected Annual Damage, Values: [1.38992705e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_18, Outcome: Dike Investment Costs, Values: [71089902.78498524], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_19, Outcome: Total Costs, Values: [2.3106335e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_19, Outcome: Expected Number of Deaths, Values: [0.00090915], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_19, Outcome: Expected Annual Damage, Values: [3657661.1679349], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_19, Outcome: Dike Investment Costs, Values: [2.27405689e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_20, Outcome: Total Costs, Values: [1.53344871e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_20, Outcome: Expected Number of Deaths, Values: [0.0062358], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_20, Outcome: Expected Annual Damage, Values: [45697706.86233296], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_20, Outcome: Dike Investment Costs, Values: [1.07647165e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_21, Outcome: Total Costs, Values: [8.75710922e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_21, Outcome: Expected Number of Deaths, Values: [0.10415646], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_21, Outcome: Expected Annual Damage, Values: [8.02020619e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_21, Outcome: Dike Investment Costs, Values: [73690303.3730879], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_22, Outcome: Total Costs, Values: [2.70528124e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_22, Outcome: Expected Number of Deaths, Values: [0.26618525], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_22, Outcome: Expected Annual Damage, Values: [2.67388244e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_22, Outcome: Dike Investment Costs, Values: [31398797.71871161], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_23, Outcome: Total Costs, Values: [1.93575151e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_23, Outcome: Expected Number of Deaths, Values: [0.01221797], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_23, Outcome: Expected Annual Damage, Values: [1.05118151e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_23, Outcome: Dike Investment Costs, Values: [88456999.3320314], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_24, Outcome: Total Costs, Values: [2.26487709e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_24, Outcome: Expected Number of Deaths, Values: [0.02888485], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_24, Outcome: Expected Annual Damage, Values: [1.38293641e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_24, Outcome: Dike Investment Costs, Values: [88194067.92528014], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_25, Outcome: Total Costs, Values: [2.61288289e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_25, Outcome: Expected Number of Deaths, Values: [0.24058983], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_25, Outcome: Expected Annual Damage, Values: [2.57227384e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_25, Outcome: Dike Investment Costs, Values: [40609051.37057717], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_26, Outcome: Total Costs, Values: [2.63558965e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_26, Outcome: Expected Number of Deaths, Values: [0.24800397], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_26, Outcome: Expected Annual Damage, Values: [2.60136809e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_26, Outcome: Dike Investment Costs, Values: [34221561.73832255], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_27, Outcome: Total Costs, Values: [1.8735797e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_27, Outcome: Expected Number of Deaths, Values: [0.00251718], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_27, Outcome: Expected Annual Damage, Values: [18556026.82738049], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_27, Outcome: Dike Investment Costs, Values: [1.68801943e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_28, Outcome: Total Costs, Values: [1.89550523e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_28, Outcome: Expected Number of Deaths, Values: [0.00277187], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_28, Outcome: Expected Annual Damage, Values: [21759860.09559748], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_28, Outcome: Dike Investment Costs, Values: [1.67790663e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_29, Outcome: Total Costs, Values: [1.86705532e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_29, Outcome: Expected Number of Deaths, Values: [0.00303175], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_29, Outcome: Expected Annual Damage, Values: [25235669.83810733], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_29, Outcome: Dike Investment Costs, Values: [1.61469863e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_30, Outcome: Total Costs, Values: [2.73809681e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_30, Outcome: Expected Number of Deaths, Values: [0.03434976], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_30, Outcome: Expected Annual Damage, Values: [1.91740172e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_30, Outcome: Dike Investment Costs, Values: [82069509.69977678], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_31, Outcome: Total Costs, Values: [2.93013235e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_31, Outcome: Expected Number of Deaths, Values: [0.32138514], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_31, Outcome: Expected Annual Damage, Values: [2.90133396e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_31, Outcome: Dike Investment Costs, Values: [28798397.13060894], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_32, Outcome: Total Costs, Values: [1.93229357e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_32, Outcome: Expected Number of Deaths, Values: [0.44187758], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_32, Outcome: Expected Annual Damage, Values: [1.87832106e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_32, Outcome: Dike Investment Costs, Values: [53972506.18695759], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_33, Outcome: Total Costs, Values: [1.76492578e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_33, Outcome: Expected Number of Deaths, Values: [0.01541769], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_33, Outcome: Expected Annual Damage, Values: [85235033.81619634], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_33, Outcome: Dike Investment Costs, Values: [91257544.08751702], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_34, Outcome: Total Costs, Values: [3.27927748e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_34, Outcome: Expected Number of Deaths, Values: [0.40349375], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_34, Outcome: Expected Annual Damage, Values: [3.2528741e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_34, Outcome: Dike Investment Costs, Values: [26403379.54230644], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_35, Outcome: Total Costs, Values: [1.93641662e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_35, Outcome: Expected Number of Deaths, Values: [0.44160455], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_35, Outcome: Expected Annual Damage, Values: [1.8756993e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_35, Outcome: Dike Investment Costs, Values: [60717312.84309486], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_36, Outcome: Total Costs, Values: [7.34826928e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_36, Outcome: Expected Number of Deaths, Values: [0.06807927], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_36, Outcome: Expected Annual Damage, Values: [6.58313861e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_36, Outcome: Dike Investment Costs, Values: [76513067.39269884], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_37, Outcome: Total Costs, Values: [4.32974651e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_37, Outcome: Expected Number of Deaths, Values: [0.64960709], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_37, Outcome: Expected Annual Damage, Values: [4.32974651e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_37, Outcome: Dike Investment Costs, Values: [0.], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_38, Outcome: Total Costs, Values: [2.61849263e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_38, Outcome: Expected Number of Deaths, Values: [0.24289383], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_38, Outcome: Expected Annual Damage, Values: [2.5812076e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_38, Outcome: Dike Investment Costs, Values: [37285037.90055943], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_39, Outcome: Total Costs, Values: [2.2381455e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_39, Outcome: Expected Number of Deaths, Values: [0.0208826], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_39, Outcome: Expected Annual Damage, Values: [1.38681564e+08], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_39, Outcome: Dike Investment Costs, Values: [85132985.86201367], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_40, Outcome: Total Costs, Values: [1.97961554e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_40, Outcome: Expected Number of Deaths, Values: [0.44734249], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_40, Outcome: Expected Annual Damage, Values: [1.93176759e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_40, Outcome: Dike Investment Costs, Values: [47847947.96145424], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_41, Outcome: Total Costs, Values: [4.09545348e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_41, Outcome: Expected Number of Deaths, Values: [0.59053036], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_41, Outcome: Expected Annual Damage, Values: [4.07125545e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_41, Outcome: Dike Investment Costs, Values: [24198032.45136138], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_42, Outcome: Total Costs, Values: [2.50427038e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_42, Outcome: Expected Number of Deaths, Values: [0.49610971], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_42, Outcome: Expected Annual Damage, Values: [2.46197887e+09], SNR: 0.0
# Scenario: reference_4, Policy: policy_4_42, Outcome: Dike Investment Costs, Values: [42291505.65437629], SNR: 0.0
# Scenario: reference_0
#             Total Costs  Expected Number of Deaths  Expected Annual Damage  \
# policy_0_0          0.0                        0.0                     0.0
# policy_0_1          0.0                        0.0                     0.0
# policy_0_2          0.0                        0.0                     0.0
# policy_0_3          0.0                        0.0                     0.0
# policy_0_4          0.0                        0.0                     0.0
#
#             Dike Investment Costs
# policy_0_0                    0.0
# policy_0_1                    0.0
# policy_0_2                    0.0
# policy_0_3                    0.0
# policy_0_4                    0.0

# %%
snr_scores['reference_3'].head()
# Out:
#             Total Costs  Expected Number of Deaths  Expected Annual Damage  \
# policy_3_0          0.0                        0.0                     0.0
# policy_3_1          0.0                        0.0                     0.0
# policy_3_2          0.0                        0.0                     0.0
# policy_3_3          0.0                        0.0                     0.0
# policy_3_4          0.0                        0.0                     0.0
#
#             Dike Investment Costs
# policy_3_0                    0.0
# policy_3_1                    0.0
# policy_3_2                    0.0
# policy_3_3                    0.0
# policy_3_4                    0.0

# %%
# Manually define the ScalarOutcome class
class ScalarOutcome:
    MINIMIZE = "MINIMIZE"
    MAXIMIZE = "MAXIMIZE"

    def __init__(self, name, kind):
        self.name = name
        self.kind = kind

# Load the data files
scenario_files = [
    'output/optimization_policies_0.csv',
    'output/optimization_policies_1.csv',
    'output/optimization_policies_2.csv',
    'output/optimization_policies_3.csv',
    'output/optimization_policies_4.csv'
]

# Column names for the outcomes
outcome_columns = ['Total Costs', 'Expected Number of Deaths', 'Expected Annual Damage', 'Dike Investment Costs']

# Dictionary to hold data for each scenario
experiments_by_scenario = {}
outcomes_by_scenario = {}
scenario_names = []

for i, file in enumerate(scenario_files):
    # Load the data
    data = pd.read_csv(file)
    scenario_name = f'Scenario_{i}'
    scenario_names.append(scenario_name)
    
    # Separate experiments and outcomes
    experiments_by_scenario[scenario_name] = data.iloc[:, :16]  # First 16 columns
    outcomes_by_scenario[scenario_name] = data.iloc[:, 16:]    # Last 4 columns
    outcomes_by_scenario[scenario_name].columns = outcome_columns

# Function to calculate SNR metric
def snr(data, direction):
    mean = np.mean(data)
    std = np.std(data)
    if direction == ScalarOutcome.MINIMIZE:
        return mean * std
    else:
        return mean / std

# Define the outcomes of interest
outcomes_of_interest = ['Total Costs', 'Expected Number of Deaths', 'Expected Annual Damage', 'Dike Investment Costs']

# Simulate multiple outcomes for each policy by adding small random noise
def simulate_outcomes(values, num_simulations=10, noise_level=0.05):
    simulated_outcomes = []
    for value in values:
        simulated = value + np.random.normal(0, noise_level * value, num_simulations)
        simulated_outcomes.append(simulated)
    return np.array(simulated_outcomes)

# Calculate SNR scores per policy per outcome and write it to a dictionary organized by scenario
snr_scores = {}
for scenario in scenario_names:
    experiment_snr_scores = {}
    for policy in experiments_by_scenario[scenario].index:
        policy_name = f's{scenario}_p{policy}'
        scores = {}
        for outcome in outcomes_of_interest:
            value = outcomes_by_scenario[scenario][outcome].iloc[policy]
            simulated_values = simulate_outcomes([value])
            sn_ratio = snr(simulated_values, ScalarOutcome.MINIMIZE)
            scores[outcome] = sn_ratio
        experiment_snr_scores[policy_name] = scores
    snr_scores[scenario] = pd.DataFrame.from_dict(experiment_snr_scores, orient='index')


snr_scores
# Out:
# {'Scenario_0':                   Total Costs  Expected Number of Deaths  \
#  sScenario_0_p0   3.533767e+15               5.055304e-07
#  sScenario_0_p1   3.719737e+15               1.088509e-07
#  sScenario_0_p2   3.356670e+15               2.574416e-06
#  sScenario_0_p3   9.048556e+16               8.331284e-04
#  sScenario_0_p4   3.968024e+15               1.495269e-05
#  ...                       ...                        ...
#  sScenario_0_p66  3.993771e+15               5.711888e-08
#  sScenario_0_p67  9.358771e+17               8.962577e-03
#  sScenario_0_p68  5.359571e+17               3.055618e-03
#  sScenario_0_p69  5.914033e+17               3.092181e-03
#  sScenario_0_p70  7.052718e+15               5.745351e-05
#
#                   Expected Annual Damage  Dike Investment Costs
#  sScenario_0_p0             6.865818e+12           2.902301e+15
#  sScenario_0_p1             5.728209e+12           3.756719e+15
#  sScenario_0_p2             2.586711e+14           1.508259e+15
#  sScenario_0_p3             7.792958e+16           3.628357e+14
#  sScenario_0_p4             9.153625e+14           1.632267e+15
#  ...                                 ...                    ...
#  sScenario_0_p66            3.564489e+12           3.756681e+15
#  sScenario_0_p67            1.272967e+18           2.097665e+13
#  sScenario_0_p68            5.488819e+17           1.812840e+14
#  sScenario_0_p69            1.129248e+18           1.747991e+14
#  sScenario_0_p70            6.363023e+15           1.045860e+15
#
#  [71 rows x 4 columns],
#  'Scenario_1':                   Total Costs  Expected Number of Deaths  \
#  sScenario_1_p0   1.544721e+16               6.698356e-05
#  sScenario_1_p1   9.936246e+17               3.675218e-03
#  sScenario_1_p2   2.551306e+16               1.188644e-03
#  sScenario_1_p3   1.336115e+15               1.377974e-06
#  sScenario_1_p4   1.878349e+16               1.304434e-04
#  sScenario_1_p5   1.996663e+15               0.000000e+00
#  sScenario_1_p6   1.290702e+16               7.635016e-05
#  sScenario_1_p7   1.181788e+16               7.132201e-05
#  sScenario_1_p8   6.473983e+17               3.621142e-03
#  sScenario_1_p9   1.936465e+16               1.096169e-04
#  sScenario_1_p10  2.190586e+15               1.184372e-06
#  sScenario_1_p11  9.578265e+14               2.218668e-07
#  sScenario_1_p12  6.431570e+16               1.012031e-03
#  sScenario_1_p13  3.274076e+16               1.450793e-04
#  sScenario_1_p14  1.052629e+15               2.127790e-06
#  sScenario_1_p15  8.586109e+17               3.010320e-03
#  sScenario_1_p16  1.238958e+15               6.502483e-07
#  sScenario_1_p17  1.428751e+16               8.393931e-05
#  sScenario_1_p18  3.779872e+16               1.457117e-04
#  sScenario_1_p19  4.787701e+16               2.075653e-04
#  sScenario_1_p20  5.127674e+17               3.816546e-03
#  sScenario_1_p21  2.319506e+15               4.298579e-06
#  sScenario_1_p22  2.717135e+15               7.028443e-06
#  sScenario_1_p23  2.595552e+16               1.644219e-04
#  sScenario_1_p24  2.491856e+15               2.216151e-06
#  sScenario_1_p25  4.541879e+15               9.351493e-06
#  sScenario_1_p26  2.082887e+15               6.179165e-06
#  sScenario_1_p27  4.579006e+16               3.062320e-04
#  sScenario_1_p28  3.363322e+16               2.017215e-04
#  sScenario_1_p29  4.759832e+15               1.432183e-05
#  sScenario_1_p30  6.177750e+15               7.391081e-05
#  sScenario_1_p31  9.482932e+15               4.751079e-05
#  sScenario_1_p32  6.471249e+16               1.277058e-03
#  sScenario_1_p33  7.997765e+15               1.035912e-04
#  sScenario_1_p34  1.853097e+15               4.265109e-08
#  sScenario_1_p35  5.391268e+17               3.707155e-03
#  sScenario_1_p36  1.224867e+15               2.029306e-07
#  sScenario_1_p37  8.743820e+17               3.583016e-03
#  sScenario_1_p38  1.812780e+15               1.030851e-08
#  sScenario_1_p39  1.620593e+15               3.064992e-09
#  sScenario_1_p40  9.167254e+14               1.202706e-08
#  sScenario_1_p41  1.679917e+15               8.037953e-10
#  sScenario_1_p42  1.148980e+15               1.213185e-08
#  sScenario_1_p43  2.426414e+15               3.516584e-07
#
#                   Expected Annual Damage  Dike Investment Costs
#  sScenario_1_p0             6.109455e+15           3.322021e+14
#  sScenario_1_p1             1.141294e+18           3.781219e+13
#  sScenario_1_p2             3.082862e+16           2.037026e+14
#  sScenario_1_p3             1.277294e+14           6.325271e+14
#  sScenario_1_p4             1.626236e+16           3.251919e+14
#  sScenario_1_p5             0.000000e+00           1.446815e+15
#  sScenario_1_p6             7.716986e+15           2.966691e+14
#  sScenario_1_p7             1.032843e+16           3.696934e+14
#  sScenario_1_p8             6.380659e+17           0.000000e+00
#  sScenario_1_p9             1.847982e+16           3.208608e+14
#  sScenario_1_p10            8.019753e+13           9.768665e+14
#  sScenario_1_p11            2.672145e+13           7.811265e+14
#  sScenario_1_p12            6.075859e+16           1.383875e+14
#  sScenario_1_p13            1.458168e+16           3.733638e+14
#  sScenario_1_p14            2.374956e+14           7.212443e+14
#  sScenario_1_p15            1.008508e+18           2.879377e+13
#  sScenario_1_p16            1.608990e+14           7.210002e+14
#  sScenario_1_p17            1.267610e+16           3.405505e+14
#  sScenario_1_p18            3.140377e+16           2.671361e+14
#  sScenario_1_p19            4.142560e+16           2.639665e+14
#  sScenario_1_p20            1.395205e+18           2.355738e+13
#  sScenario_1_p21            6.339738e+14           6.937365e+14
#  sScenario_1_p22            7.481570e+14           6.181863e+14
#  sScenario_1_p23            1.617340e+16           3.398344e+14
#  sScenario_1_p24            7.314908e+14           7.683320e+14
#  sScenario_1_p25            1.474901e+15           5.973102e+14
#  sScenario_1_p26            1.222352e+15           5.770368e+14
#  sScenario_1_p27            4.464790e+16           1.908583e+14
#  sScenario_1_p28            1.415070e+16           1.556968e+14
#  sScenario_1_p29            1.475194e+15           4.788182e+14
#  sScenario_1_p30            4.698708e+15           8.654367e+14
#  sScenario_1_p31            5.194151e+15           4.825134e+14
#  sScenario_1_p32            1.035303e+17           1.167777e+14
#  sScenario_1_p33            6.705781e+15           4.732667e+14
#  sScenario_1_p34            1.132771e+13           1.786686e+15
#  sScenario_1_p35            1.054835e+18           8.734269e+13
#  sScenario_1_p36            4.464268e+13           8.005298e+14
#  sScenario_1_p37            1.102656e+18           1.100598e+14
#  sScenario_1_p38            1.919267e+12           1.512693e+15
#  sScenario_1_p39            7.073876e+11           1.763226e+15
#  sScenario_1_p40            4.059646e+12           2.005062e+15
#  sScenario_1_p41            3.900287e+11           1.144010e+15
#  sScenario_1_p42            2.631275e+12           1.684195e+15
#  sScenario_1_p43            3.460559e+13           9.889594e+14  ,
#  'Scenario_2':                   Total Costs  Expected Number of Deaths  \
#  sScenario_2_p0   2.532687e+15               6.757439e-09
#  sScenario_2_p1   2.127199e+15               7.935824e-08
#  sScenario_2_p2   2.269783e+15               1.996944e-08
#  sScenario_2_p3   1.936280e+15               1.269970e-07
#  sScenario_2_p4   1.777172e+15               1.944129e-08
#  sScenario_2_p5   2.098238e+15               7.403533e-09
#  sScenario_2_p6   1.648647e+15               3.098053e-08
#  sScenario_2_p7   1.826190e+15               9.229598e-08
#  sScenario_2_p8   2.608593e+15               4.110907e-08
#  sScenario_2_p9   1.902193e+15               1.894451e-11
#  sScenario_2_p10  2.917711e+15               2.832306e-08
#  sScenario_2_p11  1.666720e+15               6.425583e-09
#  sScenario_2_p12  1.390918e+15               1.461716e-06
#  sScenario_2_p13  4.660171e+15               4.511249e-06
#  sScenario_2_p14  5.185338e+15               5.741703e-06
#  sScenario_2_p15  6.802094e+16               2.904552e-03
#  sScenario_2_p16  1.817376e+15               0.000000e+00
#  sScenario_2_p17  2.097620e+15               3.541526e-06
#  sScenario_2_p18  1.050824e+16               2.051200e-05
#  sScenario_2_p19  3.380959e+16               1.711422e-04
#  sScenario_2_p20  3.834092e+15               8.147439e-06
#  sScenario_2_p21  1.412610e+17               3.067690e-03
#  sScenario_2_p22  3.253641e+16               8.959635e-05
#  sScenario_2_p23  4.068272e+15               1.766658e-05
#  sScenario_2_p24  6.001506e+15               8.801534e-06
#  sScenario_2_p25  7.600317e+15               2.650642e-05
#  sScenario_2_p26  1.294866e+15               2.822524e-09
#  sScenario_2_p27  3.219233e+15               1.845563e-06
#  sScenario_2_p28  1.976741e+16               1.527359e-04
#  sScenario_2_p29  1.069997e+16               4.848078e-05
#  sScenario_2_p30  1.782353e+15               2.006562e-06
#  sScenario_2_p31  4.933230e+16               2.542253e-04
#  sScenario_2_p32  4.817039e+15               6.139218e-06
#  sScenario_2_p33  2.541269e+16               7.103144e-05
#  sScenario_2_p34  5.328232e+16               1.242519e-04
#  sScenario_2_p35  1.382249e+16               3.859742e-05
#  sScenario_2_p36  6.866116e+16               1.119719e-03
#  sScenario_2_p37  2.111479e+15               3.461040e-07
#  sScenario_2_p38  1.618569e+17               1.927612e-03
#  sScenario_2_p39  1.002445e+16               6.529791e-05
#  sScenario_2_p40  4.751524e+16               3.401327e-04
#  sScenario_2_p41  9.776239e+15               4.837351e-05
#  sScenario_2_p42  2.383747e+15               9.285584e-07
#  sScenario_2_p43  1.010771e+15               1.979372e-07
#  sScenario_2_p44  2.822703e+16               9.974768e-05
#  sScenario_2_p45  4.457607e+16               2.478514e-04
#  sScenario_2_p46  2.287168e+15               6.765242e-07
#  sScenario_2_p47  3.074259e+15               1.182437e-06
#  sScenario_2_p48  1.498034e+15               3.887574e-07
#  sScenario_2_p49  5.178255e+17               2.560715e-03
#  sScenario_2_p50  4.444844e+17               2.483668e-03
#
#                   Expected Annual Damage  Dike Investment Costs
#  sScenario_2_p0             4.433649e+12           1.629204e+15
#  sScenario_2_p1             1.406489e+13           2.086505e+15
#  sScenario_2_p2             1.341064e+12           1.925619e+15
#  sScenario_2_p3             2.387263e+13           1.241636e+15
#  sScenario_2_p4             1.977862e+12           1.963854e+15
#  sScenario_2_p5             2.605815e+11           2.264874e+15
#  sScenario_2_p6             5.882067e+12           1.766402e+15
#  sScenario_2_p7             1.231208e+13           2.081648e+15
#  sScenario_2_p8             6.971079e+12           1.959247e+15
#  sScenario_2_p9             4.288906e+09           1.943217e+15
#  sScenario_2_p10            4.434220e+12           2.001315e+15
#  sScenario_2_p11            1.131332e+12           1.157403e+15
#  sScenario_2_p12            2.161702e+14           7.570942e+14
#  sScenario_2_p13            8.876746e+14           6.917041e+14
#  sScenario_2_p14            1.569915e+15           5.586221e+14
#  sScenario_2_p15            1.365050e+17           1.307110e+14
#  sScenario_2_p16            0.000000e+00           1.761235e+15
#  sScenario_2_p17            2.402141e+14           4.253363e+14
#  sScenario_2_p18            4.674956e+15           3.723080e+14
#  sScenario_2_p19            2.719137e+16           3.014688e+14
#  sScenario_2_p20            1.628320e+15           5.398827e+14
#  sScenario_2_p21            1.094885e+17           9.186899e+13
#  sScenario_2_p22            2.005630e+16           3.939445e+14
#  sScenario_2_p23            1.175003e+15           7.037781e+14
#  sScenario_2_p24            1.605308e+15           7.746876e+14
#  sScenario_2_p25            3.853716e+15           4.041349e+14
#  sScenario_2_p26            2.203928e+11           1.936500e+15
#  sScenario_2_p27            4.978279e+14           3.880026e+14
#  sScenario_2_p28            2.999560e+16           2.586479e+14
#  sScenario_2_p29            8.546433e+15           5.289496e+14
#  sScenario_2_p30            3.165188e+14           9.521857e+14
#  sScenario_2_p31            5.212591e+16           1.895219e+14
#  sScenario_2_p32            1.338668e+15           4.419463e+14
#  sScenario_2_p33            1.109879e+16           5.610077e+14
#  sScenario_2_p34            4.263772e+16           2.663038e+14
#  sScenario_2_p35            8.644582e+15           3.697895e+14
#  sScenario_2_p36            1.121914e+17           2.671700e+14
#  sScenario_2_p37            4.756695e+13           1.128544e+15
#  sScenario_2_p38            1.656458e+17           8.740417e+13
#  sScenario_2_p39            6.718084e+15           5.295961e+14
#  sScenario_2_p40            6.135229e+16           3.065361e+14
#  sScenario_2_p41            7.502154e+15           4.423102e+14
#  sScenario_2_p42            1.983349e+14           1.175691e+15
#  sScenario_2_p43            3.206923e+13           1.718662e+15
#  sScenario_2_p44            2.021218e+16           6.555357e+14
#  sScenario_2_p45            4.510640e+16           2.845852e+14
#  sScenario_2_p46            1.639479e+14           1.220837e+15
#  sScenario_2_p47            1.710247e+14           1.191261e+15
#  sScenario_2_p48            9.679291e+13           9.962594e+14
#  sScenario_2_p49            5.212875e+17           2.337738e+13
#  sScenario_2_p50            4.689738e+17           0.000000e+00  ,
#  'Scenario_3':                   Total Costs  Expected Number of Deaths  \
#  sScenario_3_p0   3.183137e+15               5.855921e-07
#  sScenario_3_p1   4.441163e+15               5.099418e-07
#  sScenario_3_p2   2.305463e+15               1.148362e-07
#  sScenario_3_p3   3.052249e+16               5.768708e-04
#  sScenario_3_p4   4.912332e+15               2.834856e-05
#  sScenario_3_p5   2.863755e+15               7.536791e-07
#  sScenario_3_p6   6.205960e+15               1.704218e-05
#  sScenario_3_p7   1.070473e+17               3.989934e-04
#  sScenario_3_p8   1.349300e+16               8.711445e-05
#  sScenario_3_p9   3.966881e+15               4.870813e-06
#  sScenario_3_p10  2.979994e+15               1.265924e-05
#  sScenario_3_p11  2.365146e+16               1.036506e-04
#  sScenario_3_p12  9.501070e+15               5.282786e-05
#  sScenario_3_p13  6.743626e+15               2.421713e-05
#  sScenario_3_p14  3.926066e+15               1.745086e-07
#  sScenario_3_p15  2.812195e+16               2.053855e-04
#  sScenario_3_p16  3.198286e+15               3.950407e-06
#  sScenario_3_p17  6.326974e+16               6.249695e-04
#  sScenario_3_p18  4.828131e+15               1.503786e-06
#  sScenario_3_p19  3.763803e+15               4.896852e-06
#  sScenario_3_p20  1.098275e+16               2.612885e-05
#  sScenario_3_p21  7.976652e+15               2.310731e-05
#  sScenario_3_p22  2.429518e+16               2.721793e-04
#  sScenario_3_p23  3.211675e+16               3.333961e-04
#  sScenario_3_p24  4.674657e+15               6.364880e-06
#  sScenario_3_p25  8.703535e+15               3.044267e-05
#  sScenario_3_p26  4.013695e+16               4.513010e-04
#  sScenario_3_p27  6.029719e+15               1.382237e-05
#  sScenario_3_p28  5.487217e+15               5.770883e-06
#  sScenario_3_p29  4.208296e+15               2.162445e-07
#  sScenario_3_p30  1.146583e+16               3.682055e-05
#  sScenario_3_p31  1.896249e+15               2.759104e-07
#  sScenario_3_p32  7.894106e+16               5.568235e-04
#  sScenario_3_p33  8.564791e+16               5.013233e-04
#  sScenario_3_p34  3.932419e+15               7.411191e-07
#  sScenario_3_p35  3.572100e+15               1.322252e-06
#  sScenario_3_p36  4.000790e+15               8.496955e-08
#  sScenario_3_p37  3.299902e+15               2.174930e-08
#  sScenario_3_p38  2.169739e+17               1.841496e-03
#  sScenario_3_p39  4.450827e+15               6.763188e-08
#  sScenario_3_p40  1.191245e+18               4.177176e-03
#  sScenario_3_p41  5.558416e+15               1.273006e-07
#  sScenario_3_p42  3.761595e+15               1.087199e-07
#  sScenario_3_p43  2.883725e+15               1.890557e-08
#
#                   Expected Annual Damage  Dike Investment Costs
#  sScenario_3_p0             6.450566e+13           1.921414e+15
#  sScenario_3_p1             4.886369e+13           2.026441e+15
#  sScenario_3_p2             1.494236e+13           2.937021e+15
#  sScenario_3_p3             1.094434e+16           7.981810e+14
#  sScenario_3_p4             2.709645e+15           1.160166e+15
#  sScenario_3_p5             6.202448e+13           1.791519e+15
#  sScenario_3_p6             1.327945e+15           1.238366e+15
#  sScenario_3_p7             8.032149e+16           1.500998e+14
#  sScenario_3_p8             9.711895e+15           7.714182e+14
#  sScenario_3_p9             4.536381e+14           1.695456e+15
#  sScenario_3_p10            1.075516e+15           1.047854e+15
#  sScenario_3_p11            1.547649e+16           8.109396e+14
#  sScenario_3_p12            6.818066e+15           8.941042e+14
#  sScenario_3_p13            3.013124e+15           1.013161e+15
#  sScenario_3_p14            1.482958e+13           2.825113e+15
#  sScenario_3_p15            1.836401e+16           8.841519e+14
#  sScenario_3_p16            2.963856e+14           1.607065e+15
#  sScenario_3_p17            7.799317e+16           1.017866e+14
#  sScenario_3_p18            3.030868e+14           1.896436e+15
#  sScenario_3_p19            4.445664e+14           1.417567e+15
#  sScenario_3_p20            3.136570e+15           1.344448e+15
#  sScenario_3_p21            2.058625e+15           8.126090e+14
#  sScenario_3_p22            1.582238e+16           6.129243e+14
#  sScenario_3_p23            1.706370e+16           6.933085e+14
#  sScenario_3_p24            6.079995e+14           1.475994e+15
#  sScenario_3_p25            4.294577e+15           1.120349e+15
#  sScenario_3_p26            4.711815e+16           7.434933e+14
#  sScenario_3_p27            1.795446e+15           7.144603e+14
#  sScenario_3_p28            3.162760e+14           1.962261e+15
#  sScenario_3_p29            2.089565e+13           2.175382e+15
#  sScenario_3_p30            5.545900e+15           8.186600e+14
#  sScenario_3_p31            2.353124e+13           2.031866e+15
#  sScenario_3_p32            6.286462e+16           1.121665e+14
#  sScenario_3_p33            4.856668e+16           3.635310e+14
#  sScenario_3_p34            1.908850e+14           1.511250e+15
#  sScenario_3_p35            1.371099e+14           1.436908e+15
#  sScenario_3_p36            2.444788e+12           3.385386e+15
#  sScenario_3_p37            7.932906e+11           5.389175e+15
#  sScenario_3_p38            2.960763e+17           7.341357e+13
#  sScenario_3_p39            4.097009e+12           2.837051e+15
#  sScenario_3_p40            9.756854e+17           0.000000e+00
#  sScenario_3_p41            8.644065e+12           4.158764e+15
#  sScenario_3_p42            4.150777e+12           5.565244e+15
#  sScenario_3_p43            8.789397e+11           3.431095e+15  ,
#  'Scenario_4':                   Total Costs  Expected Number of Deaths  \
#  sScenario_4_p0   2.038855e+15               3.625457e-08
#  sScenario_4_p1   1.856881e+15               1.575477e-07
#  sScenario_4_p2   2.103392e+15               2.636551e-07
#  sScenario_4_p3   2.279716e+15               4.142412e-07
#  sScenario_4_p4   1.849415e+15               1.859949e-07
#  sScenario_4_p5   2.558048e+15               2.699119e-08
#  sScenario_4_p6   1.625553e+15               6.001251e-08
#  sScenario_4_p7   1.439414e+15               2.837477e-07
#  sScenario_4_p8   2.711731e+15               5.382706e-08
#  sScenario_4_p9   1.632762e+15               1.899541e-07
#  sScenario_4_p10  1.317374e+15               6.329704e-08
#  sScenario_4_p11  9.833245e+14               1.385936e-06
#  sScenario_4_p12  9.424765e+14               4.810332e-07
#  sScenario_4_p13  1.592516e+15               2.416885e-07
#  sScenario_4_p14  1.000288e+15               1.291415e-06
#  sScenario_4_p15  3.558034e+17               2.221990e-03
#  sScenario_4_p16  9.534220e+15               2.878006e-04
#  sScenario_4_p17  2.214103e+15               1.915676e-07
#  sScenario_4_p18  8.723505e+16               2.463327e-03
#  sScenario_4_p19  2.214708e+15               5.064279e-08
#  sScenario_4_p20  9.815143e+14               1.132639e-06
#  sScenario_4_p21  1.725741e+16               3.066380e-04
#  sScenario_4_p22  4.072806e+17               2.825941e-03
#  sScenario_4_p23  1.603419e+15               7.334632e-06
#  sScenario_4_p24  2.063257e+15               5.022735e-05
#  sScenario_4_p25  1.758192e+17               2.944074e-03
#  sScenario_4_p26  4.018382e+17               2.972571e-03
#  sScenario_4_p27  1.660067e+15               3.421380e-07
#  sScenario_4_p28  1.207790e+15               3.074993e-07
#  sScenario_4_p29  1.404876e+15               3.655680e-07
#  sScenario_4_p30  2.966260e+15               6.498495e-05
#  sScenario_4_p31  3.441262e+17               3.367605e-03
#  sScenario_4_p32  1.631373e+17               6.182474e-03
#  sScenario_4_p33  1.652381e+15               6.726479e-06
#  sScenario_4_p34  5.247248e+17               6.933631e-03
#  sScenario_4_p35  1.550562e+17               7.645864e-03
#  sScenario_4_p36  3.575759e+16               1.474402e-04
#  sScenario_4_p37  1.066014e+18               2.266088e-02
#  sScenario_4_p38  3.217654e+17               2.605040e-03
#  sScenario_4_p39  1.880886e+15               1.831944e-05
#  sScenario_4_p40  1.960258e+17               9.674587e-03
#  sScenario_4_p41  8.105979e+17               1.208443e-02
#  sScenario_4_p42  2.075152e+17               1.545152e-02
#
#                   Expected Annual Damage  Dike Investment Costs
#  sScenario_4_p0             3.058490e+11           2.096208e+15
#  sScenario_4_p1             6.802926e+12           1.527588e+15
#  sScenario_4_p2             3.483687e+12           2.245308e+15
#  sScenario_4_p3             7.725825e+12           1.366958e+15
#  sScenario_4_p4             4.671107e+12           2.529895e+15
#  sScenario_4_p5             9.960893e+11           1.973253e+15
#  sScenario_4_p6             1.360711e+12           1.851654e+15
#  sScenario_4_p7             8.053754e+12           1.452312e+15
#  sScenario_4_p8             1.326126e+12           1.790088e+15
#  sScenario_4_p9             3.158446e+12           2.242932e+15
#  sScenario_4_p10            3.719532e+12           1.813973e+15
#  sScenario_4_p11            9.557129e+13           4.199671e+14
#  sScenario_4_p12            6.117297e+12           1.519067e+15
#  sScenario_4_p13            6.030603e+12           1.232815e+15
#  sScenario_4_p14            1.525249e+14           4.009967e+14
#  sScenario_4_p15            2.335366e+17           7.834728e+13
#  sScenario_4_p16            6.317130e+15           3.027265e+14
#  sScenario_4_p17            1.209305e+13           7.383546e+14
#  sScenario_4_p18            5.792331e+16           2.006737e+14
#  sScenario_4_p19            5.696506e+11           2.310858e+15
#  sScenario_4_p20            9.571933e+13           7.101558e+14
#  sScenario_4_p21            2.864803e+16           2.441645e+14
#  sScenario_4_p22            3.066740e+17           6.087563e+13
#  sScenario_4_p23            4.976450e+14           2.903446e+14
#  sScenario_4_p24            7.241992e+14           3.170065e+14
#  sScenario_4_p25            1.740265e+17           5.179686e+13
#  sScenario_4_p26            3.588659e+17           4.097634e+13
#  sScenario_4_p27            1.330348e+13           1.055204e+15
#  sScenario_4_p28            2.899133e+13           1.007259e+15
#  sScenario_4_p29            3.921969e+13           1.029831e+15
#  sScenario_4_p30            1.512945e+15           3.198565e+14
#  sScenario_4_p31            5.218239e+17           3.934786e+13
#  sScenario_4_p32            1.464309e+17           1.692004e+14
#  sScenario_4_p33            2.661341e+14           2.824210e+14
#  sScenario_4_p34            3.983827e+17           2.065085e+13
#  sScenario_4_p35            1.512539e+17           1.411303e+14
#  sScenario_4_p36            1.432976e+16           2.615424e+14
#  sScenario_4_p37            4.901312e+17           0.000000e+00
#  sScenario_4_p38            2.630199e+17           7.005454e+13
#  sScenario_4_p39            8.647306e+14           3.856600e+14
#  sScenario_4_p40            1.538820e+17           1.023777e+14
#  sScenario_4_p41            7.088008e+17           2.642469e+13
#  sScenario_4_p42            3.404001e+17           6.996353e+13  }

# %%
snr_scores['Scenario_0'].head()
# Out:
#                  Total Costs  Expected Number of Deaths  \
# sScenario_0_p0  3.533767e+15               5.055304e-07
# sScenario_0_p1  3.719737e+15               1.088509e-07
# sScenario_0_p2  3.356670e+15               2.574416e-06
# sScenario_0_p3  9.048556e+16               8.331284e-04
# sScenario_0_p4  3.968024e+15               1.495269e-05
#
#                 Expected Annual Damage  Dike Investment Costs
# sScenario_0_p0            6.865818e+12           2.902301e+15
# sScenario_0_p1            5.728209e+12           3.756719e+15
# sScenario_0_p2            2.586711e+14           1.508259e+15
# sScenario_0_p3            7.792958e+16           3.628357e+14
# sScenario_0_p4            9.153625e+14           1.632267e+15

# %%
# Determine min and max values for plotting
limits = parcoords.get_limits(snr_scores[scenario_names[0]])
limits.loc[0, outcomes_of_interest] = 0

for outcome in outcomes_of_interest:
    limits.loc[1, outcome] = pd.concat(snr_scores)[outcome].max()

# Verify the limits
print(limits)
# Out:
#     Total Costs  Expected Number of Deaths  Expected Annual Damage  \
# 0  0.000000e+00                   0.000000            0.000000e+00
# 1  2.463696e+18                   0.026857            2.146702e+18
#
#    Dike Investment Costs
# 0           0.000000e+00
# 1           5.565244e+15

# %%
# Sort scenarios for consistent coloring
sorted_scenarios = sorted(experiments_by_scenario.keys())
colors = sns.color_palette("husl", len(sorted_scenarios))

# Prepare the parallel axes plot
par_axes = parcoords.ParallelAxes(limits, fontsize=10)

# Plot data for each scenario
for count, scenario in enumerate(sorted_scenarios):
    data = snr_scores[scenario]
    par_axes.plot(data, color=colors[count], label='policies from scenario ' + scenario)
    
# Set title and save the plot
plt.title('Signal-to-Noise Ratio for All Policies, Grouped by Origin Scenario', loc='right')
plt.savefig('output/snr_all_grouped_pairplot.png')

# Add legend to the plot
par_axes.legend()

# %% [markdown]
# This is a bit hard to read eventhough it is colour coded, therefore we will select a few below. What is clear for this graph is that scenario 3 generates a wide variety of policies with different SNR. The 4th scenario seems to generate many low SNR results.
#
# For better visualisation we will now plot each scenario individually.

# %%
# Iterate over each scenario and plot the SNR scores for each policy
for scenario in scenario_names:
    data = snr_scores[scenario]

    # Define a color palette
    colors = sns.color_palette("husl", data.shape[0])

    # Initialize ParallelAxes
    par_axes = parcoords.ParallelAxes(limits, fontsize=10)

    # Plot each policy's SNR score
    for i, (index, row) in enumerate(data.iterrows()):
        par_axes.plot(row.to_frame().T, label=str(index), color=colors[i])

    # Add legend to the plot
    par_axes.legend()

    # Set the title and save the plot
    plt.title(f'Signal-to-Noise Ratio for Policies from Scenario {scenario}', loc='right')
    plt.savefig(f'output/snr__all_{scenario}_pairplot.png')
    plt.show()

# %% [markdown]
# The above graphs illustrate the number of policies per scenario and allow for comparison both within and between scenarios.
#
# The plot for scenario "Scenario_4" provides the most insights into trade-offs due to the variety of SNR metric values across different outcomes. We observe that with higher Total Costs, one can achieve the lowest values in terms of Expected Annual Damage and Expected Number of Deaths. However, the damages and deaths related to Dike Investment Costs do not appear to be as sensitive to changes in Total Costs. Consequently, minimizing Total Costs increases the overall damages and deaths, but there are policies that manage to keep the damages and deaths in Dike Investment Costs relatively low.
#
# In this case, the SNR metric does not significantly help in confidently selecting a small but diverse subset of robust candidate policies by visual inspection. Therefore, we decide to filter the 50 policies down to the top 25 performers based on the Dike Investment Costs SNR score, as minimizing this is our main goal.

# %% [markdown]
# ## Supporting Dataframes
# The following sections will contain code to create:
#
# - A single dataframe for robustness scores, initially filled with SNR scores (all_data). This dataframe consolidates the SNR scores for all policies across different scenarios, making it easier for further processing and analysis.
# - A dataframe mapping each policy to the non-zero levers used (all_levers). This dataframe helps in identifying which policy levers are active for each policy, facilitating the analysis of lever usage patterns across different policies.
# The code snippets provided below accomplish these tasks step-by-step.

# %% [markdown]
# 1. Create a Dataframe for Robustness Scores
# This code snippet creates a dataframe (all_data) that consolidates the SNR scores for all policies across different scenarios. Each row represents a policy, and each column represents an SNR score for a specific outcome.

# %%
# Create a dataframe storing SNR results per policy
all_data = pd.DataFrame()

for count, scenario in enumerate(scenario_names):
    data = snr_scores[scenario]
    data['scenario'] = count
    all_data = pd.concat([all_data, data])

print(all_data.head(3))
# Out:
#                  Total Costs  Expected Number of Deaths  \
# sScenario_0_p0  3.533767e+15               5.055304e-07
# sScenario_0_p1  3.719737e+15               1.088509e-07
# sScenario_0_p2  3.356670e+15               2.574416e-06
#
#                 Expected Annual Damage  Dike Investment Costs  scenario
# sScenario_0_p0            6.865818e+12           2.902301e+15         0
# sScenario_0_p1            5.728209e+12           3.756719e+15         0
# sScenario_0_p2            2.586711e+14           1.508259e+15         0

# %% [markdown]
# 2. Extract Lever Columns and Map Policies to Non-Zero Levers
# This code snippet extracts the lever columns from the experiment data and creates a dataframe (policy_levers) that maps each policy to its respective levers. It then creates another dataframe (all_levers) that contains only the non-zero levers used by each policy.

# %%
# Extract lever columns from experiments
lever_start = experiments_by_scenario[scenario_names[0]].columns.get_loc('EWS_DaysToThreat')
lever_end = experiments_by_scenario[scenario_names[0]].columns.get_loc('A.5_DikeIncrease 2') + 1
policy_levers = experiments_by_scenario[scenario_names[0]].iloc[:, lever_start:lever_end].copy()

# Create a unique policy identifier
policy_levers['policy'] = policy_levers.index.astype(str)
print("Policy levers dataframe with policy identifier:")
print(policy_levers.head(3))
print("Columns in policy_levers dataframe:")
print(policy_levers.columns)
# Out:
# Policy levers dataframe with policy identifier:
#   policy
# 0      0
# 1      1
# 2      2
# Columns in policy_levers dataframe:
# Index(['policy'], dtype='object')

# %%
# Create a dataframe storing SNR results per policy
all_data = pd.DataFrame()

for count, scenario in enumerate(scenario_names):
    data = snr_scores[scenario]
    data['scenario'] = count
    all_data = pd.concat([all_data, data])

print("All data head (first 3 rows):")
print(all_data.head(3))

# List all columns in the dataframe to verify the correct lever columns
print("Columns in experiments_by_scenario[scenario_names[0]]:")
print(experiments_by_scenario[scenario_names[0]].columns.tolist())

# Display the first few rows of the dataframe
print("First few rows of experiments_by_scenario[scenario_names[0]]:")
print(experiments_by_scenario[scenario_names[0]].head())

# Extract lever columns from experiments
lever_columns = [
    'A.1_DikeIncrease 0', 'A.1_DikeIncrease 1', 'A.1_DikeIncrease 2', 
    'A.2_DikeIncrease 0', 'A.2_DikeIncrease 1', 'A.2_DikeIncrease 2', 
    'A.3_DikeIncrease 0', 'A.3_DikeIncrease 1', 'A.3_DikeIncrease 2', 
    'A.4_DikeIncrease 0', 'A.4_DikeIncrease 1', 'A.4_DikeIncrease 2', 
    'A.5_DikeIncrease 0', 'A.5_DikeIncrease 1', 'A.5_DikeIncrease 2', 
    'EWS_DaysToThreat'
]
policy_levers = experiments_by_scenario[scenario_names[0]][lever_columns].copy()

# Add an index column for policy identifier
policy_levers['policy'] = ['sScenario_0_p' + str(i) for i in policy_levers.index]
print("Policy levers dataframe with policy identifier:")
print(policy_levers.head(3))
print("Columns in policy_levers dataframe:")
print(policy_levers.columns)

# Create a helper dataframe containing all policies and the policy levers they activate
candidate_policies = all_data.reset_index()['index'].tolist()
print("Candidate policies:")
print(candidate_policies[:5])  # Print first 5 for verification

all_levers = pd.DataFrame()

for policy in candidate_policies:
    df = policy_levers.loc[policy_levers['policy'] == policy]
    if not df.empty:
        df = df.iloc[[0]]
        nonzero_columns = (df != 0).any()
        df = df.loc[:, nonzero_columns]
        all_levers = pd.concat([all_levers, df])

print("All levers before reindexing:")
print(all_levers.head())

all_levers = all_levers.reindex(sorted(all_levers.columns), axis=1)
all_levers.set_index('policy', inplace=True)
print("All levers after reindexing and setting index:")
print(all_levers.head())

# Select 50% most robust policies based on Dike Investment Costs SNR score
top_25 = all_data['Dike Investment Costs'].nsmallest(len(all_data) // 2).index
all_data = all_data.loc[top_25]

# Determine min and max values for plotting
limits = parcoords.get_limits(all_data)
limits.loc[0, outcomes_of_interest] = 0

for outcome in outcomes_of_interest:
    limits.loc[1, outcome] = all_data[outcome].max()

limits = limits.drop(columns=['scenario'])
print("Limits for plotting:")
print(limits)

# Plotting
colors = sns.color_palette("husl", len(scenario_names))
par_axes = parcoords.ParallelAxes(limits, fontsize=10)

for count, scenario in enumerate(scenario_names):
    data = all_data[all_data['scenario'] == count]
    par_axes.plot(data, color=colors[count], label='policies from scenario ' + scenario)

plt.title('Signal-to-Noise Ratio for Top Policies, Sorted by Origin Scenario', loc='right')
plt.savefig('output/snr_top50_grouped_pairplot.png')
par_axes.legend()
# Out:
# All data head (first 3 rows):
#                  Total Costs  Expected Number of Deaths  \
# sScenario_0_p0  3.533767e+15               5.055304e-07
# sScenario_0_p1  3.719737e+15               1.088509e-07
# sScenario_0_p2  3.356670e+15               2.574416e-06
#
#                 Expected Annual Damage  Dike Investment Costs  scenario
# sScenario_0_p0            6.865818e+12           2.902301e+15         0
# sScenario_0_p1            5.728209e+12           3.756719e+15         0
# sScenario_0_p2            2.586711e+14           1.508259e+15         0
# Columns in experiments_by_scenario[scenario_names[0]]:
# ['A.1_DikeIncrease 0', 'A.1_DikeIncrease 1', 'A.1_DikeIncrease 2', 'A.2_DikeIncrease 0', 'A.2_DikeIncrease 1', 'A.2_DikeIncrease 2', 'A.3_DikeIncrease 0', 'A.3_DikeIncrease 1', 'A.3_DikeIncrease 2', 'A.4_DikeIncrease 0', 'A.4_DikeIncrease 1', 'A.4_DikeIncrease 2', 'A.5_DikeIncrease 0', 'A.5_DikeIncrease 1', 'A.5_DikeIncrease 2', 'EWS_DaysToThreat']
# First few rows of experiments_by_scenario[scenario_names[0]]:
#    A.1_DikeIncrease 0  A.1_DikeIncrease 1  A.1_DikeIncrease 2  \
# 0                   5                   0                   0
# 1                   5                   0                   0
# 2                   5                   0                   0
# 3                   5                   0                   0
# 4                   5                   0                   0
#
#    A.2_DikeIncrease 0  A.2_DikeIncrease 1  A.2_DikeIncrease 2  \
# 0                   8                   0                   0
# 1                   6                   3                   0
# 2                   6                   0                   0
# 3                   0                   0                   0
# 4                   5                   0                   0
#
#    A.3_DikeIncrease 0  A.3_DikeIncrease 1  A.3_DikeIncrease 2  \
# 0                   9                   3                   0
# 1                  10                   2                   0
# 2                   9                   0                   0
# 3                   6                   0                   0
# 4                   8                   0                   0
#
#    A.4_DikeIncrease 0  A.4_DikeIncrease 1  A.4_DikeIncrease 2  \
# 0                   5                   0                   0
# 1                   5                   0                   0
# 2                   2                   0                   0
# 3                   0                   0                   0
# 4                   2                   0                   0
#
#    A.5_DikeIncrease 0  A.5_DikeIncrease 1  A.5_DikeIncrease 2  \
# 0                   6                   0                   0
# 1                   7                   0                   0
# 2                   4                   0                   0
# 3                   0                   0                   0
# 4                   3                   0                   0
#
#    EWS_DaysToThreat
# 0                 4
# 1                 3
# 2                 3
# 3                 3
# 4                 3
# Policy levers dataframe with policy identifier:
#    A.1_DikeIncrease 0  A.1_DikeIncrease 1  A.1_DikeIncrease 2  \
# 0                   5                   0                   0
# 1                   5                   0                   0
# 2                   5                   0                   0
#
#    A.2_DikeIncrease 0  A.2_DikeIncrease 1  A.2_DikeIncrease 2  \
# 0                   8                   0                   0
# 1                   6                   3                   0
# 2                   6                   0                   0
#
#    A.3_DikeIncrease 0  A.3_DikeIncrease 1  A.3_DikeIncrease 2  \
# 0                   9                   3                   0
# 1                  10                   2                   0
# 2                   9                   0                   0
#
#    A.4_DikeIncrease 0  A.4_DikeIncrease 1  A.4_DikeIncrease 2  \
# 0                   5                   0                   0
# 1                   5                   0                   0
# 2                   2                   0                   0
#
#    A.5_DikeIncrease 0  A.5_DikeIncrease 1  A.5_DikeIncrease 2  \
# 0                   6                   0                   0
# 1                   7                   0                   0
# 2                   4                   0                   0
#
#    EWS_DaysToThreat          policy
# 0                 4  sScenario_0_p0
# 1                 3  sScenario_0_p1
# 2                 3  sScenario_0_p2
# Columns in policy_levers dataframe:
# Index(['A.1_DikeIncrease 0', 'A.1_DikeIncrease 1', 'A.1_DikeIncrease 2',
#        'A.2_DikeIncrease 0', 'A.2_DikeIncrease 1', 'A.2_DikeIncrease 2',
#        'A.3_DikeIncrease 0', 'A.3_DikeIncrease 1', 'A.3_DikeIncrease 2',
#        'A.4_DikeIncrease 0', 'A.4_DikeIncrease 1', 'A.4_DikeIncrease 2',
#        'A.5_DikeIncrease 0', 'A.5_DikeIncrease 1', 'A.5_DikeIncrease 2',
#        'EWS_DaysToThreat', 'policy'],
#       dtype='object')
# Candidate policies:
# ['sScenario_0_p0', 'sScenario_0_p1', 'sScenario_0_p2', 'sScenario_0_p3', 'sScenario_0_p4']
# All levers before reindexing:
#    A.1_DikeIncrease 0  A.2_DikeIncrease 0  A.3_DikeIncrease 0  \
# 0                 5.0                 8.0                 9.0
# 1                 5.0                 6.0                10.0
# 2                 5.0                 6.0                 9.0
# 3                 5.0                 NaN                 6.0
# 4                 5.0                 5.0                 8.0
#
#    A.3_DikeIncrease 1  A.4_DikeIncrease 0  A.5_DikeIncrease 0  \
# 0                 3.0                 5.0                 6.0
# 1                 2.0                 5.0                 7.0
# 2                 NaN                 2.0                 4.0
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 2.0                 3.0
#
#    EWS_DaysToThreat          policy  A.2_DikeIncrease 1  A.5_DikeIncrease 1
# 0                 4  sScenario_0_p0                 NaN                 NaN
# 1                 3  sScenario_0_p1                 3.0                 NaN
# 2                 3  sScenario_0_p2                 NaN                 NaN
# 3                 3  sScenario_0_p3                 NaN                 NaN
# 4                 3  sScenario_0_p4                 NaN                 NaN
# All levers after reindexing and setting index:
#                 A.1_DikeIncrease 0  A.2_DikeIncrease 0  A.2_DikeIncrease 1  \
# policy
# sScenario_0_p0                 5.0                 8.0                 NaN
# sScenario_0_p1                 5.0                 6.0                 3.0
# sScenario_0_p2                 5.0                 6.0                 NaN
# sScenario_0_p3                 5.0                 NaN                 NaN
# sScenario_0_p4                 5.0                 5.0                 NaN
#
#                 A.3_DikeIncrease 0  A.3_DikeIncrease 1  A.4_DikeIncrease 0  \
# policy
# sScenario_0_p0                 9.0                 3.0                 5.0
# sScenario_0_p1                10.0                 2.0                 5.0
# sScenario_0_p2                 9.0                 NaN                 2.0
# sScenario_0_p3                 6.0                 NaN                 NaN
# sScenario_0_p4                 8.0                 NaN                 2.0
#
#                 A.5_DikeIncrease 0  A.5_DikeIncrease 1  EWS_DaysToThreat
# policy
# sScenario_0_p0                 6.0                 NaN                 4
# sScenario_0_p1                 7.0                 NaN                 3
# sScenario_0_p2                 4.0                 NaN                 3
# sScenario_0_p3                 NaN                 NaN                 3
# sScenario_0_p4                 3.0                 NaN                 3
# Limits for plotting:
#     Total Costs  Expected Number of Deaths  Expected Annual Damage  \
# 0  0.000000e+00                   0.000000            0.000000e+00
# 1  2.463696e+18                   0.026857            2.146702e+18
#
#    Dike Investment Costs
# 0           0.000000e+00
# 1           8.126090e+14

# %% [markdown]
# This is still a lot, however if we plot them per scenario it becomes a lot more clear

# %%
# Plotting
for count, scenario in enumerate(scenario_names):
    data = all_data[all_data['scenario'] == count]

    colors = sns.color_palette("husl", data.shape[0])
    paraxes = parcoords.ParallelAxes(limits, fontsize=10)

    for i, (index, row) in enumerate(data.iterrows()):
        paraxes.plot(row.to_frame().T, label=str(index), color=colors[i])
    paraxes.legend()
    plt.title(f'Signal-to-Noise Ratio for Policies from Scenario {scenario}', loc='right')
    plt.savefig(f'output/snr__top50_{scenario}_pairplot.png')
    plt.show()

# %% [markdown]
# After inspecting the visualizations above, the following conclusions were drawn:
#
# Note that we are only looking within origin scenarios to easily (and visually) identify dominance within a smaller selection of the candidate policy set.
#
# In terms of SNR, considering the combination of low total costs and low dike investment costs, and aiming to minimize the SNR:
#
# In scenario Scenario_0, policies sScenario_0_p9, sScenario_0_p32, and sScenario_0_p3 have relatively low SNR for both total costs and dike investment costs. Among these, sScenario_0_p32 stands out for its balanced trade-offs across all outcomes.
#
# In scenario Scenario_1, policies sScenario_1_p12, sScenario_1_p18, and sScenario_1_p9 show a good balance of low SNR for total costs and dike investment costs. Policy sScenario_1_p18 performs consistently well across the board.
#
# In scenario Scenario_2, policies sScenario_2_p24, sScenario_2_p35, and sScenario_2_p2 demonstrate lower SNR in both cost dimensions. Policy sScenario_2_p35 provides the most balanced trade-offs.
#
# In scenario Scenario_3, policies sScenario_3_p7, sScenario_3_p22, and sScenario_3_p9 exhibit the lowest SNR for the costs considered. Policy sScenario_3_p22 shows a notably balanced performance.
#
# In scenario Scenario_4, policies sScenario_4_p11, sScenario_4_p33, and sScenario_4_p21 are identified with the lowest SNR across both total costs and dike investment costs. Policy sScenario_4_p33 offers the best balance among these.

# %% [markdown]
# # Maximum regret
# in this part we will see what the effect is of selecting one policy over another. In order words, what is the regret I get for selecting policy A over policy B?

# %%
# Function to compute regret
def compute_regret(data, optimal):
    return np.abs(optimal - data)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from ema_workbench.analysis import parcoords
import numpy as np

# Load your combined data
filepaths = [
    'output/optimization_policies_0.csv',
    'output/optimization_policies_1.csv',
    'output/optimization_policies_2.csv',
    'output/optimization_policies_3.csv',
    'output/optimization_policies_4.csv'
]

experiments_list = []
outcomes_list = []

for i, filepath in enumerate(filepaths):
    data = pd.read_csv(filepath)
    experiments = data.iloc[:, :16]
    outcomes = data.iloc[:, 16:]
    experiments['policy'] = [f'policy_{i}_{j}' for j in range(len(experiments))]
    experiments['scenario'] = f'Scenario_{i}'
    experiments_list.append(experiments)
    outcomes_list.append(outcomes)

experiments = pd.concat(experiments_list, ignore_index=True)
outcomes_combined = pd.concat(outcomes_list, ignore_index=True)

# Ensure the correct scenario keys
experiments['scenario'] = experiments['scenario'].apply(lambda x: x.replace('Scenario_Scenario_', 'Scenario_'))

# Split experiments into scenarios
experiments_by_scenario = {f'Scenario_{i}': df for i, df in experiments.groupby('scenario')}
outcomes_by_scenario = {f'Scenario_{i}': {col: outcomes_combined[col][experiments['scenario'] == f'Scenario_{i}'].values for col in outcomes_combined.columns} for i in range(len(filepaths))}

# Diagnostic prints
print("Keys in experiments_by_scenario:", experiments_by_scenario.keys())
print("Keys in outcomes_by_scenario:", outcomes_by_scenario.keys())

# Function to compute regret
def compute_regret(data, optimal):
    return np.abs(optimal - data)

# List of scenarios
scenarios = list(experiments_by_scenario.keys())

# Generate a DataFrame and plots of maximum regret metric per scenario
for scenario in scenarios:
    
    regrets_dict = {}
    max_regret_dict = {}
    
    for outcome_name in outcomes_combined.columns:
        scenario_experiments = experiments_by_scenario[scenario]
        scenario_outcomes = outcomes_by_scenario[scenario]
        
        # Create a DataFrame with relevant information
        data = pd.DataFrame({
            outcome_name: scenario_outcomes[outcome_name], 
            "policy": scenario_experiments['policy'],
            "scenario_id": scenario_experiments['scenario'],
        })
        
        # Filter out rows not corresponding to the selected policies based on SNR
        data = data[data['policy'].isin(remaining_policies)]

        # Reorient data for computing regret
        data = data.pivot(index='scenario_id', columns='policy')
        data.columns = data.columns.get_level_values(1)
        
        # Calculate the regret
        outcome_regret = (data.max(axis=1).values[:, np.newaxis] - data).abs()
        
        regrets_dict[outcome_name] = outcome_regret
        max_regret_dict[outcome_name] = outcome_regret.max()

    # Plot regret heatmap
    max_regret_df = pd.DataFrame(max_regret_dict)
    sns.heatmap(max_regret_df / max_regret_df.max(), cmap='viridis', annot=True)
    plt.title(f'Regret Heatmap for Policies from {scenario}')
    plt.savefig(f'output/regret__top50_{scenario}_heatmap.png')
    plt.show()

    # Plot regret pairplot
    data = max_regret_df

    limits = parcoords.get_limits(data)
    limits.loc[0, outcomes_of_interest] = 0

    paraxes = parcoords.ParallelAxes(limits, fontsize=10)

    for i, (index, row) in enumerate(data.iterrows()):
        colors = sns.color_palette("husl", data.shape[0])
        paraxes.plot(row.to_frame().T, label=str(index), color=colors[i])
    paraxes.legend()
    plt.title(f'Maximum Regrets per Outcome in {scenario}', loc='right')
    plt.savefig(f'output/regret__top50_{scenario}_pairplot.png')
        
    plt.show()
# Out:
# Keys in experiments_by_scenario: dict_keys(['Scenario_Scenario_0', 'Scenario_Scenario_1', 'Scenario_Scenario_2', 'Scenario_Scenario_3', 'Scenario_Scenario_4'])
# Keys in outcomes_by_scenario: dict_keys(['Scenario_0', 'Scenario_1', 'Scenario_2', 'Scenario_3', 'Scenario_4'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 57
#      55 for outcome_name in outcomes_combined.columns:
#      56     scenario_experiments = experiments_by_scenario[scenario]
# ---> 57     scenario_outcomes = outcomes_by_scenario[scenario]
#      59     # Create a DataFrame with relevant information
#      60     data = pd.DataFrame({
#      61         outcome_name: scenario_outcomes[outcome_name],
#      62         "policy": scenario_experiments['policy'],
#      63         "scenario_id": scenario_experiments['scenario'],
#      64     })
#
# KeyError: 'Scenario_Scenario_0'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from ema_workbench.analysis import parcoords

# Function to compute regret
def compute_regret(data, optimal):
    return np.abs(optimal - data)

# Load the combined policies and outcomes data
combined_policies_df = pd.read_csv('output/combined_optimization_outcomes.csv')

# Separate experiments and outcomes
experiments = combined_policies_df.iloc[:, :16]
outcomes_combined = combined_policies_df.iloc[:, 16:]

# Initialize dictionaries to hold experiments and outcomes by scenario
experiments_by_scenario = {}
outcomes_by_scenario = {}

# Create separate dataframes for each scenario
scenarios = combined_policies_df['Original Scenario'].unique()
for scenario in scenarios:
    scenario_experiments = combined_policies_df[combined_policies_df['Original Scenario'] == scenario]
    experiments_by_scenario[scenario] = scenario_experiments.iloc[:, :16]
    outcomes_by_scenario[scenario] = scenario_experiments.iloc[:, 16:]

# Define the outcomes of interest
outcomes_of_interest = ['Total Costs', 'Expected Number of Deaths', 'Expected Annual Damage', 'Dike Investment Costs']

# Manually define the ScalarOutcome class
class ScalarOutcome:
    MINIMIZE = "MINIMIZE"
    MAXIMIZE = "MAXIMIZE"

# Simulate the "model" outcomes
model_outcomes = [ScalarOutcome(name, ScalarOutcome.MINIMIZE) for name in outcomes_of_interest]

# Generate a DataFrame and plots of maximum regret metric per scenario
for scenario in scenarios:
    
    regrets_dict = {}
    max_regret_dict = {}
    
    for outcome in model_outcomes:
        scenario_experiments = experiments_by_scenario[scenario]
        scenario_outcomes = outcomes_by_scenario[scenario]
        
        # Create a DataFrame with relevant information
        data = pd.DataFrame({
            outcome.name: scenario_outcomes[outcome.name], 
            "policy": scenario_experiments.index,
            "scenario_id": scenario_experiments.index,
        })
        
        # Filter out rows not corresponding to the selected policies based on SNR
        data = data[data['policy'].isin(scenario_experiments.index)]

        # Reorient data for computing regret
        data = data.pivot(index='scenario_id', columns='policy')
        data.columns = data.columns.get_level_values(1)
        
        # Calculate the regret
        outcome_regret = (data.max(axis=1).values[:, np.newaxis] - data).abs()
        
        regrets_dict[outcome.name] = outcome_regret
        max_regret_dict[outcome.name] = outcome_regret.max()

    # Plot regret heatmap
    max_regret_df = pd.DataFrame(max_regret_dict)
    sns.heatmap(max_regret_df / max_regret_df.max(), cmap='viridis', annot=True)
    plt.title(f'Regret Heatmap for Policies from {scenario}')
    plt.show()

    # Plot regret pairplot
    data = max_regret_df

    limits = parcoords.get_limits(data)
    limits.loc[0, outcomes_of_interest] = 0

    paraxes = parcoords.ParallelAxes(limits, fontsize=10)

    for i, (index, row) in enumerate(data.iterrows()):
        colors = sns.color_palette("husl", data.shape[0])
        paraxes.plot(row.to_frame().T, label=str(index), color=colors[i])
    paraxes.legend()
    plt.title(f'Maximum Regrets per Outcome in {scenario}', loc='right')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 38
#      35     MAXIMIZE = "MAXIMIZE"
#      37 # Simulate the "model" outcomes
# ---> 38 model_outcomes = [ScalarOutcome(name, ScalarOutcome.MINIMIZE) for name in outcomes_of_interest]
#      40 # Generate a DataFrame and plots of maximum regret metric per scenario
#      41 for scenario in scenarios:
#
# Cell In[27], line 38, in <listcomp>(.0)
#      35     MAXIMIZE = "MAXIMIZE"
#      37 # Simulate the "model" outcomes
# ---> 38 model_outcomes = [ScalarOutcome(name, ScalarOutcome.MINIMIZE) for name in outcomes_of_interest]
#      40 # Generate a DataFrame and plots of maximum regret metric per scenario
#      41 for scenario in scenarios:
#
# TypeError: ScalarOutcome() takes no arguments

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from ema_workbench.analysis import parcoords

# Function to compute regret
def compute_regret(data, optimal):
    return np.abs(optimal - data)

# Load the combined policies and outcomes data
combined_policies_df = pd.read_csv('output/combined_optimization_outcomes.csv')

# Define the outcomes of interest
outcomes_of_interest = ['Total Costs', 'Expected Number of Deaths', 'Expected Annual Damage', 'Dike Investment Costs']

# Separate experiments and outcomes
experiments = combined_policies_df.iloc[:, :-5]
outcomes_combined = combined_policies_df[outcomes_of_interest]

# Initialize dictionaries to hold experiments and outcomes by scenario
experiments_by_scenario = {}
outcomes_by_scenario = {}

# Create separate dataframes for each scenario
scenarios = combined_policies_df['Original Scenario'].unique()
for scenario in scenarios:
    scenario_experiments = combined_policies_df[combined_policies_df['Original Scenario'] == scenario]
    experiments_by_scenario[scenario] = scenario_experiments.iloc[:, :-5]
    outcomes_by_scenario[scenario] = scenario_experiments[outcomes_of_interest]

# Verify the data separation
for scenario in scenarios:
    print(f"Experiments columns in {scenario}:", experiments_by_scenario[scenario].columns)
    print(f"Outcomes columns in {scenario}:", outcomes_by_scenario[scenario].columns)

# Manually define the ScalarOutcome class
class ScalarOutcome:
    MINIMIZE = "MINIMIZE"
    MAXIMIZE = "MAXIMIZE"

    def __init__(self, name, kind):
        self.name = name
        self.kind = kind

# Simulate the "model" outcomes
model_outcomes = [ScalarOutcome(name, ScalarOutcome.MINIMIZE) for name in outcomes_of_interest]

# Generate a DataFrame and plots of maximum regret metric per scenario
for scenario in scenarios:
    
    regrets_dict = {}
    max_regret_dict = {}
    
    for outcome in model_outcomes:
        scenario_experiments = experiments_by_scenario[scenario]
        scenario_outcomes = outcomes_by_scenario[scenario]
        
        # Create a DataFrame with relevant information
        data = pd.DataFrame({
            outcome.name: scenario_outcomes[outcome.name], 
            "policy": scenario_experiments.index,
            "scenario_id": scenario_experiments.index,
        })
        
        # Filter out rows not corresponding to the selected policies based on SNR
        data = data[data['policy'].isin(scenario_experiments.index)]

        # Reorient data for computing regret
        data = data.pivot(index='scenario_id', columns='policy')
        data.columns = data.columns.get_level_values(1)
        
        # Calculate the regret
        outcome_regret = (data.max(axis=1).values[:, np.newaxis] - data).abs()
        
        regrets_dict[outcome.name] = outcome_regret
        max_regret_dict[outcome.name] = outcome_regret.max()

    # Plot regret heatmap
    max_regret_df = pd.DataFrame(max_regret_dict)
    sns.heatmap(max_regret_df / max_regret_df.max(), cmap='viridis', annot=True)
    plt.title(f'Regret Heatmap for Policies from {scenario}')
    plt.show()

    # Plot regret pairplot
    data = max_regret_df

    limits = parcoords.get_limits(data)
    limits.loc[0, outcomes_of_interest] = 0

    paraxes = parcoords.ParallelAxes(limits, fontsize=10)

    for i, (index, row) in enumerate(data.iterrows()):
        colors = sns.color_palette("husl", data.shape[0])
        paraxes.plot(row.to_frame().T, label=str(index), color=colors[i])
    paraxes.legend()
    plt.title(f'Maximum Regrets per Outcome in {scenario}', loc='right')
    plt.show()
# Out:
# Experiments columns in reference_0: Index(['Total Costs'], dtype='object')
# Outcomes columns in reference_0: Index(['Total Costs', 'Expected Number of Deaths', 'Expected Annual Damage',
#        'Dike Investment Costs'],
#       dtype='object')
# Experiments columns in reference_1: Index(['Total Costs'], dtype='object')
# Outcomes columns in reference_1: Index(['Total Costs', 'Expected Number of Deaths', 'Expected Annual Damage',
#        'Dike Investment Costs'],
#       dtype='object')
# Experiments columns in reference_2: Index(['Total Costs'], dtype='object')
# Outcomes columns in reference_2: Index(['Total Costs', 'Expected Number of Deaths', 'Expected Annual Damage',
#        'Dike Investment Costs'],
#       dtype='object')
# Experiments columns in reference_3: Index(['Total Costs'], dtype='object')
# Outcomes columns in reference_3: Index(['Total Costs', 'Expected Number of Deaths', 'Expected Annual Damage',
#        'Dike Investment Costs'],
#       dtype='object')
# Experiments columns in reference_4: Index(['Total Costs'], dtype='object')
# Outcomes columns in reference_4: Index(['Total Costs', 'Expected Number of Deaths', 'Expected Annual Damage',
#        'Dike Investment Costs'],
#       dtype='object')
# C:\Users\Joost\PycharmProjects\venv\lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\Joost\PycharmProjects\venv\lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# C:\Users\Joost\PycharmProjects\venv\lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\Joost\PycharmProjects\venv\lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# C:\Users\Joost\PycharmProjects\venv\lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\Joost\PycharmProjects\venv\lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# C:\Users\Joost\PycharmProjects\venv\lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\Joost\PycharmProjects\venv\lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# C:\Users\Joost\PycharmProjects\venv\lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\Joost\PycharmProjects\venv\lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
